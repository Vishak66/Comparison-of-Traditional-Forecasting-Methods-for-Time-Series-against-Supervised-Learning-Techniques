# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/international-airline-passengers.csv",usecols=[1])
df.head()
# Out:
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
df.describe()
# Out:
#        International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# count                                         144.000000
# mean                                          280.298611
# std                                           119.966317
# min                                           104.000000
# 25%                                           180.000000
# 50%                                           265.500000
# 75%                                           360.500000
# max                                           622.000000

# %%
plt.figure(figsize = (15, 5))
plt.plot(df, label = "Airline Passengers")
plt.xlabel("Months")
plt.ylabel("1000 International Airline Passengers")
plt.title("Monthly Total Airline Passengers 1949 - 1960")
plt.legend()
plt.show()

# %%
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller
from statsmodels.tsa.stattools import acf,pacf

# %%
def TestStationaryPlot(ts):
    rol_mean = ts.rolling(window = 12, center = False).mean()
    rol_std = ts.rolling(window = 12, center = False).std()
    
    plt.plot(ts, color = 'blue',label = 'Original Data')
    plt.plot(rol_mean, color = 'red', label = 'Rolling Mean')
    plt.plot(rol_std, color ='black', label = 'Rolling Std')
    plt.xticks(fontsize = 10)
    plt.yticks(fontsize = 10)
    
    plt.xlabel('Time in Years', fontsize = 10)
    plt.ylabel('Total Emissions', fontsize = 10)
    plt.legend(loc='best', fontsize = 10)
    plt.title('Rolling Mean & Standard Deviation', fontsize = 25)
    plt.show(block= True)

# %%
def TestStationaryAdfuller(ts, cutoff = 0.01):
    ts_test = adfuller(ts, autolag = 'AIC')
    ts_test_output = pd.Series(ts_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    
    for key,value in ts_test[4].items():
        ts_test_output['Critical Value (%s)'%key] = value
    print(ts_test_output)
    
    if ts_test[1] <= cutoff:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary")
    else:
        print("Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
TestStationaryPlot(df)

# %%
df = df.dropna()

# %%
TestStationaryAdfuller(df.iloc[:,0])
# Out:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64
# Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df_first_difference = df - df.shift(1)  
TestStationaryPlot(df_first_difference.dropna(inplace=False))

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df_first_difference.dropna(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df_first_difference.dropna(), lags=40, ax=ax2)
# Out:
# C:\Users\visha\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
diff12 = df_first_difference - df_first_difference.shift(12)  
TestStationaryPlot(diff12.dropna(inplace=False))

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(diff12.dropna(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(diff12.dropna(), lags=40, ax=ax2)

# %%
TestStationaryAdfuller(diff12.iloc[:,0].dropna())
# Out:
# Test Statistic                -1.559562e+01
# p-value                        1.856512e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.300000e+02
# Critical Value (1%)           -3.481682e+00
# Critical Value (5%)           -2.884042e+00
# Critical Value (10%)          -2.578770e+00
# dtype: float64
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary

# %%
ts = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/international-airline-passengers.csv")
ts.head()
# Out:
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
ts = ts.dropna()

# %%
ts.reset_index(inplace=True)
ts['Month'] = pd.to_datetime(ts['Month'])
ts = ts.set_index('Month')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

fig,ax = plt.subplots()
fig.set_size_inches(20,15)
plt.subplot(411)
plt.plot(ts, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# C:\Users\visha\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:491: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return x[reverse].conj()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(residual.iloc[:,1].dropna(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(residual.iloc[:,1].dropna(), lags=40, ax=ax2)

# %%
TestStationaryAdfuller(residual.iloc[:,1].dropna())
# Out:
# Test Statistic                  -5.298428
# p-value                          0.000006
# #Lags Used                      13.000000
# Number of Observations Used    118.000000
# Critical Value (1%)             -3.487022
# Critical Value (5%)             -2.886363
# Critical Value (10%)            -2.580009
# dtype: float64
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary

# %% [markdown]
# ## Choose differencing

# %%
mod = sm.tsa.statespace.SARIMAX(ts.iloc[:130,1].dropna(), 
                                order=(0,1,1), 
                                seasonal_order=(0,1,1,12),   
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
# C:\Users\visha\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                                          Statespace Model Results
# ==========================================================================================================================================
# Dep. Variable:     International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60   No. Observations:                  130
# Model:                                                             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -391.017
# Date:                                                                            Sun, 02 Dec 2018   AIC                            788.034
# Time:                                                                                    19:39:38   BIC                            795.938
# Sample:                                                                                01-01-1949   HQIC                           791.236
#                                                                                      - 10-01-1959
# Covariance Type:                                                                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2237      0.090     -2.491      0.013      -0.400      -0.048
# ma.S.L12      -0.0799      0.094     -0.854      0.393      -0.264       0.104
# sigma2       116.1267     16.362      7.097      0.000      84.058     148.195
# ===================================================================================
# Ljung-Box (Q):                       47.69   Jarque-Bera (JB):                 0.19
# Prob(Q):                              0.19   Prob(JB):                         0.91
# Heteroskedasticity (H):               1.39   Skew:                             0.04
# Prob(H) (two-sided):                  0.34   Kurtosis:                         3.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\visha\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start = 130, end = 143, dynamic=False)
pred_ci = pred.conf_int()
pred_ci.head()
# Out:
#             lower International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60  \
# 1959-11-01                                         339.627295
# 1959-12-01                                         361.358472
# 1960-01-01                                         378.243667
# 1960-02-01                                         355.951749
# 1960-03-01                                         414.801987
#
#             upper International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 1959-11-01                                         381.869261
# 1959-12-01                                         414.833692
# 1960-01-01                                         440.971768
# 1960-02-01                                         426.733314
# 1960-03-01                                         492.809970

# %%
fig,axi = plt.subplots() 
fig.set_size_inches(20,15)
ax = ts.iloc[:,1].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='b', alpha=.5)

ax.set_xlabel('Time (years)')
ax.set_ylabel('NG CO2 Emissions')
plt.legend()

plt.show()

# %%
mte_forecast = pred.predicted_mean
mte_truth = ts.iloc[130:,1]

# Compute the mean square error
mse = ((mte_forecast - mte_truth) ** 2).mean()
print('The Mean Squared Error (MSE) of the forecast is {}'.format(round(mse, 2)))
print('The Root Mean Square Error (RMSE) of the forcast: {:.4f}'
      .format(np.sqrt(mse)))

arima_rmse = np.sqrt(mse)
# Out:
# The Mean Squared Error (MSE) of the forecast is 230.92
# The Root Mean Square Error (RMSE) of the forcast: 15.1961

# %%
# Get forecast of 10 years or 120 months steps ahead in future
forecast = results.get_forecast(steps= 24)
# Get confidence intervals of forecasts
forecast_ci = forecast.conf_int()
forecast_ci.head()
# Out:
#             lower International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60  \
# 1959-11-01                                         339.627295
# 1959-12-01                                         361.358472
# 1960-01-01                                         378.243667
# 1960-02-01                                         355.951749
# 1960-03-01                                         414.801987
#
#             upper International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 1959-11-01                                         381.869261
# 1959-12-01                                         414.833692
# 1960-01-01                                         440.971768
# 1960-02-01                                         426.733314
# 1960-03-01                                         492.809970

# %%
ax = ts.iloc[:,1].plot(label='observed', figsize=(20, 15))
forecast.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(forecast_ci.index,
                forecast_ci.iloc[:, 0],
                forecast_ci.iloc[:, 1], color='g', alpha=.4)
ax.set_xlabel('Time (year)')
ax.set_ylabel('NG CO2 Emission level')

plt.legend()
plt.show()

# %% [markdown]
# # DCNN

# %%
df1 = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/international-airline-passengers.csv")
df1.head()
# Out:
#      Month  \
# 0  1949-01
# 1  1949-02
# 2  1949-03
# 3  1949-04
# 4  1949-05
#
#    International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                              112.0
# 1                                              118.0
# 2                                              132.0
# 3                                              129.0
# 4                                              121.0

# %%
df1 = df1.dropna()

# %%
df1.Month = pd.to_datetime(df1.iloc[:,0])

# %%
df1['month_year'] = df1.Month.dt.to_period('M')

# %%
df1.Month = df1.month_year

# %%
df1 = df1.drop(['month_year'],axis=1)

# %%
data_start_date = df1.iloc[0,0]
data_end_date = df1.iloc[df1.shape[0]-1,0]
print('Data ranges from %s to %s' % (data_start_date, data_end_date))
# Out:
# Data ranges from 1949-01 to 1960-12

# %%
from datetime import timedelta

pred_steps = 12

first_day = data_start_date 
last_day = data_end_date

val_pred_start = last_day - pred_steps 
val_pred_end = last_day - 1

train_pred_start = val_pred_start - pred_steps
train_pred_end = val_pred_start - 1

# %%
enc_length = train_pred_start - first_day

train_enc_start = first_day
train_enc_end = train_enc_start + enc_length - 1

val_enc_start = train_enc_start + pred_steps 
val_enc_end = val_enc_start + enc_length - 1

# %%
print('Train encoding:', train_enc_start, '-', train_enc_end)
print('Train prediction:', train_pred_start, '-', train_pred_end, '\n')
print('Val encoding:', val_enc_start, '-', val_enc_end)
print('Val prediction:', val_pred_start, '-', val_pred_end)
# Out:
# Train encoding: 1949-01 - 1958-11
# Train prediction: 1958-12 - 1959-11
#
# Val encoding: 1950-01 - 1959-11
# Val prediction: 1959-12 - 1960-11

# %%
date_to_index = pd.Series(index=pd.Index([c for c in df1.iloc[:,0]]),
                          data=[i for i in range(len(df1.iloc[:,0]))])

series_array = df1.iloc[:,1]

def get_time_block_series(series_array, date_to_index, start_date, end_date):
    
    inds = date_to_index[start_date:end_date]
    return series_array[inds]

def transform_series_encode(series_array):
    
  
    series_mean = series_array.mean(axis=0) 
    series_array = series_array 
    series_array = series_array.values.reshape((1,series_array.shape[0], 1))
    
    return series_array, series_mean

def transform_series_decode(series_array, encode_series_mean):

    series_array = series_array 
    series_array = series_array.values.reshape((1,series_array.shape[0],1))
    
    return series_array

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, Dense, Dropout, Lambda, concatenate
from keras.optimizers import Adam

# convolutional layer parameters
n_filters = 64 
filter_width = 2
dilation_rates = [2**i for i in range(4)] 

# define an input history series and pass it through a stack of dilated causal convolutions. 
history_seq = Input(shape=(None, 1))
x = history_seq

for dilation_rate in dilation_rates:
    x = Conv1D(filters=n_filters,
               kernel_size=filter_width, 
               padding='causal',
               dilation_rate=dilation_rate)(x)

x = Dense(8, activation='relu')(x)
x = Dense(1)(x)

# extract the last 14 time steps as the training target
def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':12})(x)

model = Model(history_seq, pred_seq_train)

# %%
first_n_samples = 144
epochs = 100

# sample of series from train_enc_start to train_enc_end  
encoder_input_data = get_time_block_series(series_array, date_to_index, 
                                           train_enc_start, train_enc_end)
encoder_input_data, encode_series_mean = transform_series_encode(encoder_input_data)

# sample of series from train_pred_start to train_pred_end 
decoder_target_data = get_time_block_series(series_array, date_to_index, 
                                            train_pred_start, train_pred_end)
decoder_target_data = transform_series_decode(decoder_target_data, encode_series_mean)


# we append a lagged history of the target series to the input data, 
# so that we can train with teacher forcing
lagged_target_history = decoder_target_data[:,:-1,:1]

encoder_input_data = np.concatenate([encoder_input_data, lagged_target_history], axis=1)
print(encoder_input_data.shape,decoder_target_data.shape)
model.compile(Adam(lr=0.001), loss='mean_absolute_error')
history = model.fit(encoder_input_data, decoder_target_data,
                    epochs=epochs)
# Out:
# (1, 130, 1) (1, 12, 1)
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 325.7822
# Epoch 2/100
# 1/1 [==============================] - 0s 11ms/step - loss: 216.5070
# Epoch 3/100
# 1/1 [==============================] - 0s 15ms/step - loss: 61.4200
# Epoch 4/100
# 1/1 [==============================] - 0s 14ms/step - loss: 165.9802
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 180.5907
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 111.4702
# Epoch 7/100
# 1/1 [==============================] - 0s 10ms/step - loss: 41.9935
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 88.5110
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 103.3122
# Epoch 10/100
# 1/1 [==============================] - 0s 10ms/step - loss: 86.8238
# Epoch 11/100
# 1/1 [==============================] - 0s 7ms/step - loss: 65.1180
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 59.0802
# Epoch 13/100
# 1/1 [==============================] - 0s 10ms/step - loss: 74.3911
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 82.1151
# Epoch 15/100
# 1/1 [==============================] - 0s 6ms/step - loss: 78.6007
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 64.2279
# Epoch 17/100
# 1/1 [==============================] - 0s 12ms/step - loss: 45.4196
# Epoch 18/100
# 1/1 [==============================] - 0s 9ms/step - loss: 39.1556
# Epoch 19/100
# 1/1 [==============================] - 0s 10ms/step - loss: 37.9861
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 36.4337
# Epoch 21/100
# 1/1 [==============================] - 0s 9ms/step - loss: 37.9743
# Epoch 22/100
# 1/1 [==============================] - 0s 10ms/step - loss: 35.2286
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 33.7402
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 34.8471
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 30.0097
# Epoch 26/100
# 1/1 [==============================] - 0s 10ms/step - loss: 28.6940
# Epoch 27/100
# 1/1 [==============================] - 0s 21ms/step - loss: 28.2924
# Epoch 28/100
# 1/1 [==============================] - 0s 8ms/step - loss: 26.6444
# Epoch 29/100
# 1/1 [==============================] - 0s 5ms/step - loss: 23.8527
# Epoch 30/100
# 1/1 [==============================] - 0s 5ms/step - loss: 25.3696
# Epoch 31/100
# 1/1 [==============================] - 0s 7ms/step - loss: 21.8894
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 23.9184
# Epoch 33/100
# 1/1 [==============================] - 0s 7ms/step - loss: 21.8747
# Epoch 34/100
# 1/1 [==============================] - 0s 6ms/step - loss: 20.2392
# Epoch 35/100
# 1/1 [==============================] - 0s 5ms/step - loss: 22.0584
# Epoch 36/100
# 1/1 [==============================] - 0s 7ms/step - loss: 20.4530
# Epoch 37/100
# 1/1 [==============================] - 0s 5ms/step - loss: 23.2374
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 20.3995
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 19.0446
# Epoch 40/100
# 1/1 [==============================] - 0s 7ms/step - loss: 19.7377
# Epoch 41/100
# 1/1 [==============================] - 0s 5ms/step - loss: 18.8184
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 17.1914
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 18.5560
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 16.3636
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 18.3481
# Epoch 46/100
# 1/1 [==============================] - 0s 5ms/step - loss: 16.7243
# Epoch 47/100
# 1/1 [==============================] - 0s 4ms/step - loss: 17.9831
# Epoch 48/100
# 1/1 [==============================] - 0s 8ms/step - loss: 15.0125
# Epoch 49/100
# 1/1 [==============================] - 0s 7ms/step - loss: 17.6353
# Epoch 50/100
# 1/1 [==============================] - 0s 6ms/step - loss: 16.4780
# Epoch 51/100
# 1/1 [==============================] - 0s 6ms/step - loss: 16.9867
# Epoch 52/100
# 1/1 [==============================] - 0s 7ms/step - loss: 13.4466
# Epoch 53/100
# 1/1 [==============================] - 0s 4ms/step - loss: 18.5610
# Epoch 54/100
# 1/1 [==============================] - 0s 7ms/step - loss: 17.9287
# Epoch 55/100
# 1/1 [==============================] - 0s 4ms/step - loss: 13.3680
# Epoch 56/100
# 1/1 [==============================] - 0s 5ms/step - loss: 12.6591
# Epoch 57/100
# 1/1 [==============================] - 0s 8ms/step - loss: 14.0152
# Epoch 58/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.4262
# Epoch 59/100
# 1/1 [==============================] - 0s 6ms/step - loss: 16.1573
# Epoch 60/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.5491
# Epoch 61/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.8159
# Epoch 62/100
# 1/1 [==============================] - 0s 5ms/step - loss: 12.5189
# Epoch 63/100
# 1/1 [==============================] - 0s 6ms/step - loss: 14.4757
# Epoch 64/100
# 1/1 [==============================] - 0s 8ms/step - loss: 14.4594
# Epoch 65/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.5214
# Epoch 66/100
# 1/1 [==============================] - 0s 8ms/step - loss: 17.9177
# Epoch 67/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.2553
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 12.4631
# Epoch 69/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.7337
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.8457
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.5095
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.4881
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 15.9338
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 12.1409
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 18.5573
# Epoch 76/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.6782
# Epoch 77/100
# 1/1 [==============================] - 0s 6ms/step - loss: 19.6790
# Epoch 78/100
# 1/1 [==============================] - 0s 4ms/step - loss: 21.3668
# Epoch 79/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.8234
# Epoch 80/100
# 1/1 [==============================] - 0s 6ms/step - loss: 23.8842
# Epoch 81/100
# 1/1 [==============================] - 0s 7ms/step - loss: 14.2974
# Epoch 82/100
# 1/1 [==============================] - 0s 7ms/step - loss: 19.9212
# Epoch 83/100
# 1/1 [==============================] - 0s 6ms/step - loss: 24.3012
# Epoch 84/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.0505
# Epoch 85/100
# 1/1 [==============================] - 0s 7ms/step - loss: 27.0149
# Epoch 86/100
# 1/1 [==============================] - 0s 6ms/step - loss: 23.1602
# Epoch 87/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.3474
# Epoch 88/100
# 1/1 [==============================] - 0s 5ms/step - loss: 19.4502
# Epoch 89/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.6121
# Epoch 90/100
# 1/1 [==============================] - 0s 6ms/step - loss: 18.7786
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 14.4342
# Epoch 92/100
# 1/1 [==============================] - 0s 5ms/step - loss: 11.7448
# Epoch 93/100
# 1/1 [==============================] - 0s 7ms/step - loss: 16.0798
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.3199
# Epoch 95/100
# 1/1 [==============================] - 0s 7ms/step - loss: 14.1922
# Epoch 96/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.8844
# Epoch 97/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9646
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 13.3485
# Epoch 99/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.0778
# Epoch 100/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.3045

# %%
def predict_sequence(input_sequence):

    history_sequence = input_sequence.copy()
    pred_sequence = np.zeros((1,pred_steps+2,1)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps+2):
        
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)[0,-1,0]
        pred_sequence[0,i,0] = last_step_pred
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence, 
                                           last_step_pred.reshape(-1,1,1)], axis=1)

    return pred_sequence

# %%
def predict_and_plot(encoder_input_data, decoder_target_data, sample_ind, enc_tail_len=144):


    
    encode_series = encoder_input_data[sample_ind:sample_ind+1,:,:] 
    pred_series = predict_sequence(encode_series)
    
    decoder_target_data = get_time_block_series(series_array, date_to_index, 
                                            val_pred_start-1, val_pred_end+1)
    decoder_target_data = transform_series_decode(decoder_target_data, encode_series_mean)
    
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ind,:,:1].reshape(-1,1) 
    
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
  
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1),encode_series_tail)
    plt.plot(range(x_encode,x_encode+pred_steps+2),target_series,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps+2),pred_series[:],color='teal',linestyle='--')
    plt.xlabel("Time(in Years)")
    plt.ylabel("No. of Passengers")
    
    plt.title('Airline Passengers Data')
    plt.legend(['Original Series','Target Series','Predictions'])

# %%
predict_and_plot(encoder_input_data, decoder_target_data, 0)

# %%
encode_series = encoder_input_data[0:1,:,:] 

pred_series = predict_sequence(encode_series)
pred_series = pred_series.reshape(-1,1)

mte_truth = df1.iloc[130:144,1]
mte_truth = mte_truth.values.reshape(-1,1)

# Compute the mean square error
mse = ((pred_series - mte_truth) ** 2).mean()
print('The Mean Squared Error (MSE) of the forecast is {}'.format(round(mse, 2)))
print('The Root Mean Square Error (RMSE) of the forcast: {}'
      .format(np.sqrt(mse)))

DCNN_rmse = np.sqrt(mse)
# Out:
# The Mean Squared Error (MSE) of the forecast is 1511.58
# The Root Mean Square Error (RMSE) of the forcast: 38.8789964592474

# %% [markdown]
# # LSTM

# %%
import math

# %%
ap = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/international-airline-passengers.csv",usecols = [1])

# %%
ap=ap.dropna()
ap.shape
# Out:
# (144, 1)

# %%
plt.figure(figsize = (15, 5))
plt.plot(ap, label = "Airline Passengers")
plt.xlabel("Months")
plt.ylabel("1000 International Airline Passengers")
plt.title("Monthly Total Airline Passengers 1949 - 1960")
plt.legend()
plt.show()

# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

# %%
ap = ap.values.astype("float32")
type(ap)
# Out:
# numpy.ndarray

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
ap_scaled = scaler.fit_transform(ap)
type(ap_scaled)
# Out:
# numpy.ndarray

# %%
train_size = 130
test_size = len(ap_scaled) - train_size
train, test = ap_scaled[0:train_size, :], ap_scaled[train_size:len(ap_scaled), :]
print("Number of entries (training set, test set): " + str((len(train), len(test))))
# Out:
# Number of entries (training set, test set): (130, 14)

# %%
def create_dataset(dataset, window_size = 1):
    data_X = dataset[:(len(dataset) - window_size)]
    data_Y = np.roll(dataset, -1)[:-1]
    return(data_X, data_Y.reshape(len(data_Y),))

# %%
window_size = 1
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# Original training data shape:
# (129, 1)
# (129,)
# (13, 1)
# (13,)

# %%
# Reshape the input data into appropriate form for Keras.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print("New training data shape:")
print(train_X.shape)
print(test_X.shape)
# Out:
# New training data shape:
# (129, 1, 1)
# (13, 1, 1)

# %%
def fit_model(train_X, train_Y, window_size = 1):
    model = Sequential()
    
    model.add(LSTM(3, 
                   input_shape = (1, window_size)))
    model.add(Dense(1))
    model.compile(loss = "mean_squared_error", 
                  optimizer = "adam")
    model.fit(train_X, 
              train_Y, 
              epochs = 100, 
              batch_size = 1, 
              verbose = 2)
    
    return(model)

# %%
model_ap = fit_model(train_X, train_Y, window_size)
# Out:
# Epoch 1/100
#  - 2s - loss: 0.1234
# Epoch 2/100
#  - 0s - loss: 0.0660
# Epoch 3/100
#  - 0s - loss: 0.0466
# Epoch 4/100
#  - 0s - loss: 0.0409
# Epoch 5/100
#  - 0s - loss: 0.0379
# Epoch 6/100
#  - 0s - loss: 0.0356
# Epoch 7/100
#  - 0s - loss: 0.0333
# Epoch 8/100
#  - 0s - loss: 0.0309
# Epoch 9/100
#  - 0s - loss: 0.0285
# Epoch 10/100
#  - 0s - loss: 0.0258
# Epoch 11/100
#  - 0s - loss: 0.0233
# Epoch 12/100
#  - 0s - loss: 0.0207
# Epoch 13/100
#  - 0s - loss: 0.0182
# Epoch 14/100
#  - 0s - loss: 0.0157
# Epoch 15/100
#  - 0s - loss: 0.0132
# Epoch 16/100
#  - 0s - loss: 0.0110
# Epoch 17/100
#  - 0s - loss: 0.0092
# Epoch 18/100
#  - 0s - loss: 0.0077
# Epoch 19/100
#  - 0s - loss: 0.0062
# Epoch 20/100
#  - 0s - loss: 0.0052
# Epoch 21/100
#  - 0s - loss: 0.0047
# Epoch 22/100
#  - 0s - loss: 0.0042
# Epoch 23/100
#  - 0s - loss: 0.0039
# Epoch 24/100
#  - 0s - loss: 0.0037
# Epoch 25/100
#  - 0s - loss: 0.0036
# Epoch 26/100
#  - 0s - loss: 0.0036
# Epoch 27/100
#  - 0s - loss: 0.0035
# Epoch 28/100
#  - 0s - loss: 0.0036
# Epoch 29/100
#  - 0s - loss: 0.0035
# Epoch 30/100
#  - 0s - loss: 0.0035
# Epoch 31/100
#  - 0s - loss: 0.0034
# Epoch 32/100
#  - 0s - loss: 0.0037
# Epoch 33/100
#  - 0s - loss: 0.0036
# Epoch 34/100
#  - 0s - loss: 0.0035
# Epoch 35/100
#  - 0s - loss: 0.0035
# Epoch 36/100
#  - 0s - loss: 0.0035
# Epoch 37/100
#  - 0s - loss: 0.0036
# Epoch 38/100
#  - 0s - loss: 0.0035
# Epoch 39/100
#  - 0s - loss: 0.0035
# Epoch 40/100
#  - 0s - loss: 0.0036
# Epoch 41/100
#  - 0s - loss: 0.0035
# Epoch 42/100
#  - 0s - loss: 0.0035
# Epoch 43/100
#  - 0s - loss: 0.0035
# Epoch 44/100
#  - 0s - loss: 0.0035
# Epoch 45/100
#  - 0s - loss: 0.0036
# Epoch 46/100
#  - 0s - loss: 0.0035
# Epoch 47/100
#  - 0s - loss: 0.0035
# Epoch 48/100
#  - 0s - loss: 0.0035
# Epoch 49/100
#  - 0s - loss: 0.0035
# Epoch 50/100
#  - 0s - loss: 0.0035
# Epoch 51/100
#  - 0s - loss: 0.0035
# Epoch 52/100
#  - 0s - loss: 0.0035
# Epoch 53/100
#  - 0s - loss: 0.0035
# Epoch 54/100
#  - 0s - loss: 0.0035
# Epoch 55/100
#  - 0s - loss: 0.0035
# Epoch 56/100
#  - 0s - loss: 0.0035
# Epoch 57/100
#  - 0s - loss: 0.0035
# Epoch 58/100
#  - 0s - loss: 0.0035
# Epoch 59/100
#  - 0s - loss: 0.0035
# Epoch 60/100
#  - 0s - loss: 0.0034
# Epoch 61/100
#  - 0s - loss: 0.0035
# Epoch 62/100
#  - 0s - loss: 0.0036
# Epoch 63/100
#  - 0s - loss: 0.0034
# Epoch 64/100
#  - 0s - loss: 0.0035
# Epoch 65/100
#  - 0s - loss: 0.0035
# Epoch 66/100
#  - 0s - loss: 0.0035
# Epoch 67/100
#  - 0s - loss: 0.0035
# Epoch 68/100
#  - 0s - loss: 0.0035
# Epoch 69/100
#  - 0s - loss: 0.0035
# Epoch 70/100
#  - 0s - loss: 0.0035
# Epoch 71/100
#  - 0s - loss: 0.0035
# Epoch 72/100
#  - 0s - loss: 0.0034
# Epoch 73/100
#  - 0s - loss: 0.0034
# Epoch 74/100
#  - 0s - loss: 0.0035
# Epoch 75/100
#  - 0s - loss: 0.0035
# Epoch 76/100
#  - 0s - loss: 0.0035
# Epoch 77/100
#  - 0s - loss: 0.0035
# Epoch 78/100
#  - 0s - loss: 0.0034
# Epoch 79/100
#  - 0s - loss: 0.0035
# Epoch 80/100
#  - 0s - loss: 0.0035
# Epoch 81/100
#  - 0s - loss: 0.0034
# Epoch 82/100
#  - 0s - loss: 0.0036
# Epoch 83/100
#  - 0s - loss: 0.0034
# Epoch 84/100
#  - 0s - loss: 0.0034
# Epoch 85/100
#  - 0s - loss: 0.0034
# Epoch 86/100
#  - 0s - loss: 0.0035
# Epoch 87/100
#  - 0s - loss: 0.0035
# Epoch 88/100
#  - 0s - loss: 0.0035
# Epoch 89/100
#  - 0s - loss: 0.0034
# Epoch 90/100
#  - 0s - loss: 0.0035
# Epoch 91/100
#  - 0s - loss: 0.0035
# Epoch 92/100
#  - 0s - loss: 0.0034
# Epoch 93/100
#  - 0s - loss: 0.0034
# Epoch 94/100
#  - 0s - loss: 0.0035
# Epoch 95/100
#  - 0s - loss: 0.0034
# Epoch 96/100
#  - 0s - loss: 0.0035
# Epoch 97/100
#  - 0s - loss: 0.0034
# Epoch 98/100
#  - 0s - loss: 0.0035
# Epoch 99/100
#  - 0s - loss: 0.0035
# Epoch 100/100
#  - 0s - loss: 0.0034

# %%
def predict_and_score(model, X, Y):
    # Make predictions on the original scale of the data.
    pred = scaler.inverse_transform(model.predict(X))
    # Prepare Y data to also be on the original scale for interpretability.
    orig_data = scaler.inverse_transform([Y])
    # Calculate RMSE.
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return(score, pred)

rmse_train, train_predict = predict_and_score(model_ap, train_X, train_Y)
rmse_test, test_predict = predict_and_score(model_ap, test_X, test_Y)

print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
# Out:
# Training data score: 30.23 RMSE
# Test data score: 53.55 RMSE

# %%
LSTM_rmse = rmse_test

# %%
def shift(l, n):
       return l[n:] + l[:n]
    

# Start with training predictions.
train_predict_plot = np.empty_like(ap_scaled)
train_predict_plot[:, :] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict

# Add test predictions.
test_predict_plot = np.empty_like(ap_scaled)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + window_size:len(ap_scaled) - 1, :] = test_predict
# Create the plot.
plt.figure(figsize = (15, 5))
plt.plot(scaler.inverse_transform(ap_scaled), label = "True value")
plt.plot(np.roll(train_predict_plot,-1), label = "Training set prediction")
plt.plot(test_predict_plot, label = "Test set prediction")
plt.xlabel("Months")
plt.ylabel("1000 International Airline Passengers")
plt.title("Comparison true vs. predicted training / test")
plt.legend()
plt.show()

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error
import imageio
import os
from statsmodels.graphics.tsaplots import plot_acf

# %%
df1 = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/international-airline-passengers.csv",index_col=[0])
df1.head()
# Out:
#          International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# Month
# 1949-01                                              112.0
# 1949-02                                              118.0
# 1949-03                                              132.0
# 1949-04                                              129.0
# 1949-05                                              121.0

# %%
df1 = df1.dropna()

df1.reset_index(inplace=True)

df1['Month'] = pd.to_datetime(df1['Month'])

df1 = df1.set_index('Month')

# %%
def split_data(data, split_date):
    return data[data.index <= split_date].copy(), \
           data[data.index >  split_date].copy()

# %%
train, test = split_data(df1,'1959-10')

plt.figure(figsize=(15,5))
plt.xlabel('time')
plt.ylabel('energy consumed')
plt.plot(train.index,train)
plt.plot(test.index,test)
plt.show()

# %%
def create_features(df):
    df['date'] = df.index
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    
    X = df[['year','month']]
    return X

# %%
X_train, y_train = create_features(train), train.iloc[:,0]
X_test, y_test   = create_features(test), test.iloc[:,0]

X_train.shape, y_train.shape
# Out:
# ((130, 2), (130,))

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,eval_set=[(X_train, y_train), (X_test, y_test)],early_stopping_rounds=50,verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
def plot_performance(base_data, date_from, date_to, title=None):
    plt.figure(figsize=(15,3))
    if title == None:
        plt.title('From {0} To {1}'.format(date_from, date_to))
    else:
        plt.title(title)
    plt.xlabel('time')
    plt.ylabel('energy consumed')
    plt.plot(df1.index,df1, label='data')
    plt.plot(X_test.index,X_test_pred, label='prediction')
    plt.legend()
    plt.xlim(left=date_from, right=date_to)

# %%
X_test_pred = reg.predict(X_test)
    
plot_performance(df1, df1.index[0].date(), df1.index[-1].date(),
                 'Original and Predicted Data')

plot_performance(y_test, y_test.index[0].date(), y_test.index[-1].date(),
                 'Test and Predicted Data')


plt.legend()

plt.show()

# %%
print("RMSE",np.sqrt(mean_squared_error(y_true=y_test,y_pred=X_test_pred)))
# Out:
# RMSE 48.38181260870448

# %%
XGBOOST_rmse = np.sqrt(mean_squared_error(y_true=y_test,y_pred=X_test_pred))

# %%
arima = ts.iloc[:,1]
arima_predicted = pred.predicted_mean

fig,axi = plt.subplots() 
fig.set_size_inches(20,8)
plt.plot(df1.index[80:],arima[80:],label='Observed')
plt.plot(df1.index[130:],arima_predicted[:],label='ARIMA',linestyle='--')
plt.plot(df1.index[130:],pred_series,label='DCNN',linestyle='--')
plt.plot(df1.index[130:],test_predict_plot[130:],label="LSTM",linestyle='--')
plt.plot(df1.index[130:],X_test_pred ,label='XGBOOST',linestyle='--')
plt.xlabel("Time(in Years)")
plt.ylabel("No. of Passengers")
plt.title("Airline Passenger Data")
plt.legend(fontsize='x-large')
plt.grid()

# %%
RMSE = []
RMSE.append(arima_rmse)
RMSE.append(DCNN_rmse)
RMSE.append(LSTM_rmse)
RMSE.append(XGBOOST_rmse)

# %%
x=np.asarray(RMSE)

# %%
import seaborn as sns

sns.barplot(x=['ARIMA','DCNN','LSTM','XGBOOST'],y=x, palette="rocket")
plt.title("RMSE")
plt.ylabel("RMSE values")
