# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/z.csv")
df.head()
# Out:
#      Month  Sunspot
# 0  1749-01     58.0
# 1  1749-02     62.6
# 2  1749-03     70.0
# 3  1749-04     55.7
# 4  1749-05     85.0

# %%
df.describe()
# Out:
#            Sunspot
# count  2820.000000
# mean     51.265957
# std      43.448971
# min       0.000000
# 25%      15.700000
# 50%      42.000000
# 75%      74.925000
# max     253.800000

# %%
plt.figure(figsize = (15, 5))
plt.plot(df['Sunspot'], label = "Sunspot number")
plt.xlabel("Months")
plt.ylabel("Sunspot number")
plt.title("Plot of Sunspots")
plt.legend()
plt.show()

# %%
import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller
from statsmodels.tsa.stattools import acf,pacf

# %%
def TestStationaryPlot(ts):
    rol_mean = ts.rolling(window = 12, center = False).mean()
    rol_std = ts.rolling(window = 12, center = False).std()
    
    plt.plot(ts, color = 'blue',label = 'Original Data')
    plt.plot(rol_mean, color = 'red', label = 'Rolling Mean')
    plt.plot(rol_std, color ='black', label = 'Rolling Std')
    plt.xticks(fontsize = 10)
    plt.yticks(fontsize = 10)
    
    plt.xlabel('Time in Years', fontsize = 10)
    plt.ylabel('Total Emissions', fontsize = 10)
    plt.legend(loc='best', fontsize = 10)
    plt.title('Rolling Mean & Standard Deviation', fontsize = 25)
    plt.show(block= True)

# %%
def TestStationaryAdfuller(ts, cutoff = 0.01):
    ts_test = adfuller(ts, autolag = 'AIC')
    ts_test_output = pd.Series(ts_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    
    for key,value in ts_test[4].items():
        ts_test_output['Critical Value (%s)'%key] = value
    print(ts_test_output)
    
    if ts_test[1] <= cutoff:
        print("Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary")
    else:
        print("Weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
df1 = df.copy()
df1[df1.iloc[:,1]==0] = 1

# %%
any(df1.iloc[:,1]<=0)
# Out:
# False

# %%
import scipy

fig,ax = plt.subplots()

scipy.stats.boxcox_normplot(df1.iloc[:,1], -2, 2, plot=ax, N=80)
# Out:
# (array([-2.        , -1.94936709, -1.89873418, -1.84810127, -1.79746835,
#         -1.74683544, -1.69620253, -1.64556962, -1.59493671, -1.5443038 ,
#         -1.49367089, -1.44303797, -1.39240506, -1.34177215, -1.29113924,
#         -1.24050633, -1.18987342, -1.13924051, -1.08860759, -1.03797468,
#         -0.98734177, -0.93670886, -0.88607595, -0.83544304, -0.78481013,
#         -0.73417722, -0.6835443 , -0.63291139, -0.58227848, -0.53164557,
#         -0.48101266, -0.43037975, -0.37974684, -0.32911392, -0.27848101,
#         -0.2278481 , -0.17721519, -0.12658228, -0.07594937, -0.02531646,
#          0.02531646,  0.07594937,  0.12658228,  0.17721519,  0.2278481 ,
#          0.27848101,  0.32911392,  0.37974684,  0.43037975,  0.48101266,
#          0.53164557,  0.58227848,  0.63291139,  0.6835443 ,  0.73417722,
#          0.78481013,  0.83544304,  0.88607595,  0.93670886,  0.98734177,
#          1.03797468,  1.08860759,  1.13924051,  1.18987342,  1.24050633,
#          1.29113924,  1.34177215,  1.39240506,  1.44303797,  1.49367089,
#          1.5443038 ,  1.59493671,  1.64556962,  1.69620253,  1.74683544,
#          1.79746835,  1.84810127,  1.89873418,  1.94936709,  2.        ]),
#  array([0.21176308, 0.21853922, 0.22577726, 0.23351308, 0.24178516,
#         0.25063455, 0.26010484, 0.2702421 , 0.2810946 , 0.29271255,
#         0.30514758, 0.31845206, 0.33267819, 0.34787685, 0.36409613,
#         0.38137955, 0.39976394, 0.419277  , 0.43993462, 0.46173784,
#         0.48466982, 0.5086927 , 0.53374462, 0.55973721, 0.58655347,
#         0.61404671, 0.64204043, 0.67032968, 0.69868409, 0.72685262,
#         0.75457034, 0.78156686, 0.80757614, 0.83234705, 0.85565369,
#         0.87730463, 0.89715002, 0.91508593, 0.93105559, 0.94504754,
#         0.95709116, 0.96725039, 0.97561633, 0.9822996 , 0.98742314,
#         0.99111588, 0.99350752, 0.99472455, 0.99488739, 0.99410862,
#         0.99249192, 0.99013174, 0.98711338, 0.9835134 , 0.97940023,
#         0.97483483, 0.96987144, 0.96455829, 0.95893826, 0.95304948,
#         0.94692595, 0.94059797, 0.93409261, 0.92743407, 0.92064403,
#         0.91374194, 0.90674525, 0.89966963, 0.89252919, 0.8853366 ,
#         0.87810328, 0.87083948, 0.86355446, 0.85625651, 0.84895311,
#         0.84165097, 0.8343561 , 0.82707392, 0.81980926, 0.81256645]))

# %%
dfnew = df1.iloc[:,1]**0.4

# %%
TestStationaryPlot(dfnew)

# %%
df = df.dropna()

# %%
TestStationaryAdfuller(dfnew)
# Out:
# Test Statistic                -9.324404e+00
# p-value                        9.697661e-16
# #Lags Used                     2.600000e+01
# Number of Observations Used    2.793000e+03
# Critical Value (1%)           -3.432693e+00
# Critical Value (5%)           -2.862575e+00
# Critical Value (10%)          -2.567321e+00
# dtype: float64
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dfnew, lags=400, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dfnew, lags=400, ax=ax2)

# %%
df_first_difference = dfnew - dfnew.shift(1)  
TestStationaryPlot(df_first_difference.dropna(inplace=False))

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df_first_difference.dropna(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df_first_difference.dropna(), lags=40, ax=ax2)

# %%
TestStationaryAdfuller(df_first_difference.dropna())
# Out:
# Test Statistic                -8.600862e+00
# p-value                        6.875187e-14
# #Lags Used                     2.300000e+01
# Number of Observations Used    2.795000e+03
# Critical Value (1%)           -3.432692e+00
# Critical Value (5%)           -2.862575e+00
# Critical Value (10%)          -2.567321e+00
# dtype: float64
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary

# %%
diff12 = df_first_difference - df_first_difference.shift(130)  
TestStationaryPlot(diff12.dropna(inplace=False))

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(diff12.dropna(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(diff12.dropna(), lags=40, ax=ax2)

# %%
TestStationaryAdfuller(diff12.dropna())
# Out:
# Test Statistic                -1.038793e+01
# p-value                        2.056644e-18
# #Lags Used                     2.800000e+01
# Number of Observations Used    2.660000e+03
# Critical Value (1%)           -3.432811e+00
# Critical Value (5%)           -2.862627e+00
# Critical Value (10%)          -2.567349e+00
# dtype: float64
# Strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root, hence it is stationary

# %% [markdown]
# ## Choose differencing

# %%
mod = sm.tsa.statespace.SARIMAX(dfnew[:2300].dropna(), 
                                order=(8,1,2),seasonal_order=(0,1,0,130),  
                                  
                                enforce_stationarity=True,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary())
# Out:
#                                   Statespace Model Results
# ===========================================================================================
# Dep. Variable:                             Sunspot   No. Observations:                 2300
# Model:             SARIMAX(8, 1, 2)x(0, 1, 0, 130)   Log Likelihood               -2828.221
# Date:                             Sun, 02 Dec 2018   AIC                           5678.443
# Time:                                     19:53:20   BIC                           5740.945
# Sample:                                          0   HQIC                          5701.298
#                                             - 2300
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5981      0.249     -2.398      0.016      -1.087      -0.109
# ar.L2         -0.4343      0.204     -2.129      0.033      -0.834      -0.035
# ar.L3         -0.3275      0.119     -2.755      0.006      -0.560      -0.094
# ar.L4         -0.2635      0.091     -2.908      0.004      -0.441      -0.086
# ar.L5         -0.1669      0.070     -2.390      0.017      -0.304      -0.030
# ar.L6         -0.1018      0.051     -2.009      0.044      -0.201      -0.003
# ar.L7         -0.1093      0.033     -3.310      0.001      -0.174      -0.045
# ar.L8         -0.0953      0.024     -3.958      0.000      -0.143      -0.048
# ma.L1          0.0707      0.251      0.282      0.778      -0.421       0.562
# ma.L2         -0.0006      0.216     -0.003      0.998      -0.423       0.422
# sigma2         0.7943      0.022     36.472      0.000       0.752       0.837
# ===================================================================================
# Ljung-Box (Q):                       61.60   Jarque-Bera (JB):                27.31
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.97   Skew:                             0.09
# Prob(H) (two-sided):                  0.69   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start = 2300, end = 2821, dynamic=False)
pred_ci = pred.conf_int()
pred_ci.head()
# Out:
#       lower Sunspot  upper Sunspot
# 2300       4.893230       8.386812
# 2301       5.253601       9.117706
# 2302       4.000049       8.056293
# 2303       3.458490       7.671714
# 2304       2.726236       7.070702

# %%
pred.predicted_mean
# Out:
# 2300     6.640021
# 2301     7.185653
# 2302     6.028171
# 2303     5.565102
# 2304     4.898469
# 2305     4.975417
# 2306     4.937984
# 2307     4.612487
# 2308     4.262142
# 2309     4.406050
# 2310     4.768532
# 2311     4.877178
# 2312     4.945854
# 2313     4.442653
# 2314     3.688287
# 2315     5.268644
# 2316     4.664779
# 2317     4.731956
# 2318     4.371987
# 2319     3.746794
# 2320     3.902827
# 2321     3.558581
# 2322     4.016573
# 2323     3.280989
# 2324     3.995062
# 2325     3.932074
# 2326     3.479945
# 2327     3.340285
# 2328     3.397408
# 2329     3.397247
#           ...
# 2792    10.027095
# 2793     9.321766
# 2794    10.790292
# 2795     9.764339
# 2796     9.114186
# 2797     9.362565
# 2798     9.912184
# 2799     9.196902
# 2800     8.855214
# 2801     8.770802
# 2802     8.373536
# 2803     9.609027
# 2804     9.824060
# 2805     9.410504
# 2806     9.324327
# 2807     9.529252
# 2808     9.692070
# 2809     9.073545
# 2810     8.486535
# 2811     7.539651
# 2812     7.876600
# 2813     8.198652
# 2814     8.940632
# 2815     8.243208
# 2816     8.021602
# 2817     8.957493
# 2818     8.467415
# 2819     9.521926
# 2820     9.715788
# 2821    10.261421
# Length: 522, dtype: float64

# %%
arima = dfnew.copy()

fig,axi = plt.subplots() 
fig.set_size_inches(20,15)
ax = arima.plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='b', alpha=.5)

ax.set_xlabel('Time (years)')
ax.set_ylabel('NG CO2 Emissions')
plt.legend()

plt.show()

# %%
ax = dfnew.plot(label='observed')

# %%
rescaled_original = dfnew**(1/0.4)
rescaled_predicted = pred.predicted_mean**(1/0.4)

# %%
rescaled_predicted
# Out:
# 2300    113.611847
# 2301    138.409424
# 2302     89.220347
# 2303     73.060534
# 2304     53.106893
# 2305     55.217122
# 2306     54.184398
# 2307     45.691758
# 2308     37.503335
# 2309     40.749616
# 2310     49.654868
# 2311     52.531709
# 2312     54.400535
# 2313     41.601208
# 2314     26.125338
# 2315     63.715805
# 2316     46.997807
# 2317     48.708165
# 2318     39.966600
# 2319     27.173739
# 2320     30.091798
# 2321     23.888684
# 2322     32.332484
# 2323     19.498987
# 2324     31.901324
# 2325     30.658742
# 2326     22.590759
# 2327     20.391959
# 2328     21.274990
# 2329     21.272459
#            ...
# 2792    318.374199
# 2793    265.305008
# 2794    382.457305
# 2795    297.925087
# 2796    250.781049
# 2797    268.217495
# 2798    309.330924
# 2799    256.509736
# 2800    233.344522
# 2801    227.823392
# 2802    202.895438
# 2803    286.219043
# 2804    302.501491
# 2805    271.664071
# 2806    265.487314
# 2807    280.315445
# 2808    292.443091
# 2809    247.994769
# 2810    209.809900
# 2811    156.091083
# 2812    174.119327
# 2813    192.466947
# 2814    239.012483
# 2815    195.092529
# 2816    182.243795
# 2817    240.140965
# 2818    208.630188
# 2819    279.777005
# 2820    294.235538
# 2821    337.301876
# Length: 522, dtype: float64

# %%
fig,axi = plt.subplots() 
fig.set_size_inches(20,15)
ax = rescaled_original.plot(label='observed')
rescaled_predicted.plot(ax=ax, label='One-step ahead forecast', alpha=.7)


ax.set_xlabel('Time (months)')
ax.set_ylabel('Sunspots')
plt.legend()

plt.show()

# %%
mte_forecast = pred.predicted_mean
mte_truth = rescaled_original[2300:]

# Compute the mean square error
mse = ((mte_forecast - mte_truth) ** 2).mean()
print('The Mean Squared Error (MSE) of the forecast is {}'.format(round(mse, 2)))
print('The Root Mean Square Error (RMSE) of the forcast: {:.4f}'
      .format(np.sqrt(mse)))
# Out:
# The Mean Squared Error (MSE) of the forecast is 7905.65
# The Root Mean Square Error (RMSE) of the forcast: 88.9137

# %%
arima_rmse = np.sqrt(mse)

# %% [markdown]
# # DCNN

# %%
df1 = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/z.csv")
df1.head()
# Out:
#      Month  Sunspot
# 0  1749-01     58.0
# 1  1749-02     62.6
# 2  1749-03     70.0
# 3  1749-04     55.7
# 4  1749-05     85.0

# %%
df1 = df1.dropna()

# %%
df1.Month = pd.to_datetime(df1.iloc[:,0])

# %%
df1['month_year'] = df1.Month.dt.to_period('M')

# %%
df1.Month = df1.month_year

# %%
df1 = df1.drop(['month_year'],axis=1)

# %%
data_start_date = df1.iloc[0,0]
data_end_date = df1.iloc[df1.shape[0]-1,0]
print('Data ranges from %s to %s' % (data_start_date, data_end_date))
# Out:
# Data ranges from 1749-01 to 1983-12

# %%
from datetime import timedelta

pred_steps = 500

first_day = data_start_date 
last_day = data_end_date

val_pred_start = last_day - pred_steps 
val_pred_end = last_day - 1

train_pred_start = val_pred_start - pred_steps
train_pred_end = val_pred_start - 1

# %%
enc_length = train_pred_start - first_day

train_enc_start = first_day
train_enc_end = train_enc_start + enc_length - 1

val_enc_start = train_enc_start + pred_steps 
val_enc_end = val_enc_start + enc_length - 1

# %%
print('Train encoding:', train_enc_start, '-', train_enc_end)
print('Train prediction:', train_pred_start, '-', train_pred_end, '\n')
print('Val encoding:', val_enc_start, '-', val_enc_end)
print('Val prediction:', val_pred_start, '-', val_pred_end)
# Out:
# Train encoding: 1749-01 - 1900-07
# Train prediction: 1900-08 - 1942-03
#
# Val encoding: 1790-09 - 1942-03
# Val prediction: 1942-04 - 1983-11

# %%
date_to_index = pd.Series(index=pd.Index([c for c in df1.iloc[:,0]]),
                          data=[i for i in range(len(df1.iloc[:,0]))])

series_array = df1.iloc[:,1]

def get_time_block_series(series_array, date_to_index, start_date, end_date):
    
    inds = date_to_index[start_date:end_date]
    return series_array[inds]

def transform_series_encode(series_array):
    
  
    series_mean = series_array.mean(axis=0) 
    series_array = series_array 
    series_array = series_array.values.reshape((1,series_array.shape[0], 1))
    
    return series_array, series_mean

def transform_series_decode(series_array, encode_series_mean):

    series_array = series_array 
    series_array = series_array.values.reshape((1,series_array.shape[0],1))
    
    return series_array

# %%
from keras.models import Model
from keras.layers import Input, Conv1D, Dense, Dropout, Lambda, concatenate
from keras.optimizers import Adam

# convolutional layer parameters
n_filters = 512 
filter_width = 2
dilation_rates = [2**i for i in range(8)] 

# define an input history series and pass it through a stack of dilated causal convolutions. 
history_seq = Input(shape=(None, 1))
x = history_seq

for dilation_rate in dilation_rates:
    x = Conv1D(filters=n_filters,
               kernel_size=filter_width, 
               padding='causal',
               dilation_rate=dilation_rate)(x)

x = Dense(2000, activation='relu')(x)
x = Dense(1)(x)


def slice(x, seq_length):
    return x[:,-seq_length:,:]

pred_seq_train = Lambda(slice, arguments={'seq_length':500})(x)

model = Model(history_seq, pred_seq_train)
# Out:
# Using TensorFlow backend.

# %%
first_n_samples = 3000
epochs = 100


# sample of series from train_enc_start to train_enc_end  
encoder_input_data = get_time_block_series(series_array, date_to_index, 
                                           train_enc_start, train_enc_end)
encoder_input_data, encode_series_mean = transform_series_encode(encoder_input_data)

# sample of series from train_pred_start to train_pred_end 
decoder_target_data = get_time_block_series(series_array, date_to_index, 
                                            train_pred_start, train_pred_end)
decoder_target_data = transform_series_decode(decoder_target_data, encode_series_mean)


# we append a lagged history of the target series to the input data, 
# so that we can train with teacher forcing
lagged_target_history = decoder_target_data[:,:-1,:1]

encoder_input_data = np.concatenate([encoder_input_data, lagged_target_history], axis=1)
print(encoder_input_data.shape,decoder_target_data.shape)
model.compile(Adam(lr=0.0001), loss='mean_absolute_error')
history = model.fit(encoder_input_data, decoder_target_data,
                    epochs=epochs)
# Out:
# (1, 2318, 1) (1, 500, 1)
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 42.6173
# Epoch 2/100
# 1/1 [==============================] - 1s 1s/step - loss: 31.5917
# Epoch 3/100
# 1/1 [==============================] - 1s 1s/step - loss: 24.9447
# Epoch 4/100
# 1/1 [==============================] - 1s 1s/step - loss: 23.9694
# Epoch 5/100
# 1/1 [==============================] - 1s 1s/step - loss: 18.1671
# Epoch 6/100
# 1/1 [==============================] - 1s 1s/step - loss: 17.1226
# Epoch 7/100
# 1/1 [==============================] - 1s 1s/step - loss: 18.1782
# Epoch 8/100
# 1/1 [==============================] - 1s 1s/step - loss: 16.2837
# Epoch 9/100
# 1/1 [==============================] - 1s 1s/step - loss: 15.7495
# Epoch 10/100
# 1/1 [==============================] - 1s 1s/step - loss: 14.8165
# Epoch 11/100
# 1/1 [==============================] - 2s 2s/step - loss: 14.1487
# Epoch 12/100
# 1/1 [==============================] - 1s 1s/step - loss: 14.7651
# Epoch 13/100
# 1/1 [==============================] - 2s 2s/step - loss: 13.4195
# Epoch 14/100
# 1/1 [==============================] - 2s 2s/step - loss: 12.4562
# Epoch 15/100
# 1/1 [==============================] - 1s 1s/step - loss: 13.0331
# Epoch 16/100
# 1/1 [==============================] - 2s 2s/step - loss: 12.6192
# Epoch 17/100
# 1/1 [==============================] - 1s 1s/step - loss: 12.4753
# Epoch 18/100
# 1/1 [==============================] - 1s 1s/step - loss: 11.7028
# Epoch 19/100
# 1/1 [==============================] - 2s 2s/step - loss: 11.9622
# Epoch 20/100
# 1/1 [==============================] - 1s 1s/step - loss: 11.9394
# Epoch 21/100
# 1/1 [==============================] - 2s 2s/step - loss: 11.3534
# Epoch 22/100
# 1/1 [==============================] - 1s 1s/step - loss: 11.4367
# Epoch 23/100
# 1/1 [==============================] - 1s 1s/step - loss: 10.9069
# Epoch 24/100
# 1/1 [==============================] - 1s 1s/step - loss: 11.2298
# Epoch 25/100
# 1/1 [==============================] - 2s 2s/step - loss: 10.5197
# Epoch 26/100
# 1/1 [==============================] - 1s 1s/step - loss: 10.5920
# Epoch 27/100
# 1/1 [==============================] - 2s 2s/step - loss: 10.4208
# Epoch 28/100
# 1/1 [==============================] - 2s 2s/step - loss: 10.3564
# Epoch 29/100
# 1/1 [==============================] - 1s 1s/step - loss: 10.1682
# Epoch 30/100
# 1/1 [==============================] - 1s 1s/step - loss: 10.0086
# Epoch 31/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.9597
# Epoch 32/100
# 1/1 [==============================] - 2s 2s/step - loss: 9.8198
# Epoch 33/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.6564
# Epoch 34/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.7585
# Epoch 35/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.5425
# Epoch 36/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.4519
# Epoch 37/100
# 1/1 [==============================] - 2s 2s/step - loss: 9.2952
# Epoch 38/100
# 1/1 [==============================] - 2s 2s/step - loss: 9.3439
# Epoch 39/100
# 1/1 [==============================] - 1s 1s/step - loss: 9.1409
# Epoch 40/100
# 1/1 [==============================] - 2s 2s/step - loss: 9.0720
# Epoch 41/100
# 1/1 [==============================] - 2s 2s/step - loss: 9.0894
# Epoch 42/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.9320
# Epoch 43/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.8423
# Epoch 44/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.7953
# Epoch 45/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.7352
# Epoch 46/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.6693
# Epoch 47/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.7448
# Epoch 48/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.6800
# Epoch 49/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.4555
# Epoch 50/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.8903
# Epoch 51/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.5191
# Epoch 52/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.3061
# Epoch 53/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.5729
# Epoch 54/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.4174
# Epoch 55/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.1402
# Epoch 56/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.0869
# Epoch 57/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.0512
# Epoch 58/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.3547
# Epoch 59/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.0929
# Epoch 60/100
# 1/1 [==============================] - 2s 2s/step - loss: 8.0657
# Epoch 61/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.0787
# Epoch 62/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.9435
# Epoch 63/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.8070
# Epoch 64/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.7415
# Epoch 65/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.7828
# Epoch 66/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.6973
# Epoch 67/100
# 1/1 [==============================] - 2s 2s/step - loss: 7.7015
# Epoch 68/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.7513
# Epoch 69/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.8152
# Epoch 70/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.7316
# Epoch 71/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.6547
# Epoch 72/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.6029
# Epoch 73/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.5168
# Epoch 74/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.5107
# Epoch 75/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.5490
# Epoch 76/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.3048
# Epoch 77/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.2160
# Epoch 78/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.0947
# Epoch 79/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.0756
# Epoch 80/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.0920
# Epoch 81/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.2437
# Epoch 82/100
# 1/1 [==============================] - 1s 1s/step - loss: 8.0800
# Epoch 83/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.4944
# Epoch 84/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.9365
# Epoch 85/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.7901
# Epoch 86/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.8970
# Epoch 87/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.6867
# Epoch 88/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.5996
# Epoch 89/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.7061
# Epoch 90/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.2468
# Epoch 91/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.8827
# Epoch 92/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.7513
# Epoch 93/100
# 1/1 [==============================] - 1s 1s/step - loss: 7.0837
# Epoch 94/100
# 1/1 [==============================] - 2s 2s/step - loss: 7.5814
# Epoch 95/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.6918
# Epoch 96/100
# 1/1 [==============================] - 2s 2s/step - loss: 6.4529
# Epoch 97/100
# 1/1 [==============================] - 2s 2s/step - loss: 6.7869
# Epoch 98/100
# 1/1 [==============================] - 2s 2s/step - loss: 6.9785
# Epoch 99/100
# 1/1 [==============================] - 2s 2s/step - loss: 6.6617
# Epoch 100/100
# 1/1 [==============================] - 1s 1s/step - loss: 6.2949

# %%
def predict_sequence(input_sequence):

    history_sequence = input_sequence.copy()
    pred_sequence = np.zeros((1,pred_steps+2,1)) # initialize output (pred_steps time steps)  
    
    for i in range(pred_steps+2):
        
        # record next time step prediction (last time step of model output) 
        last_step_pred = model.predict(history_sequence)[0,-1,0]
        pred_sequence[0,i,0] = last_step_pred
        
        # add the next time step prediction to the history sequence
        history_sequence = np.concatenate([history_sequence, 
                                           last_step_pred.reshape(-1,1,1)], axis=1)

    return pred_sequence

# %%
def predict_and_plot(encoder_input_data, decoder_target_data, sample_ind, enc_tail_len=3000):


    
    encode_series = encoder_input_data[sample_ind:sample_ind+1,:,:] 
    pred_series = predict_sequence(encode_series)
    
    decoder_target_data = get_time_block_series(series_array, date_to_index, 
                                            val_pred_start-1, val_pred_end+1)
    decoder_target_data = transform_series_decode(decoder_target_data, encode_series_mean)
    
    encode_series = encode_series.reshape(-1,1)
    pred_series = pred_series.reshape(-1,1)   
    target_series = decoder_target_data[sample_ind,:,:1].reshape(-1,1) 
    
    encode_series_tail = np.concatenate([encode_series[-enc_tail_len:],target_series[:1]])
    x_encode = encode_series_tail.shape[0]
  
    plt.figure(figsize=(10,6))   
    
    plt.plot(range(1,x_encode+1),encode_series_tail)
    plt.plot(range(x_encode,x_encode+pred_steps+2),target_series,color='orange')
    plt.plot(range(x_encode,x_encode+pred_steps+2),pred_series[:],color='teal',linestyle='--')
    plt.xlabel("Time(in months)")
    plt.ylabel("No. of Sunspots")
    
    plt.title('Sunspots Data')
    plt.legend(['Original Series','Target Series','Predictions'])

# %%
predict_and_plot(encoder_input_data, decoder_target_data, 0)

# %%
encode_series = encoder_input_data[0:1,:,:] 

pred_series = predict_sequence(encode_series)
pred_series = pred_series.reshape(-1,1)

mte_truth = df1.iloc[2318:,1]
mte_truth = mte_truth.values.reshape(-1,1)

# Compute the mean square error
mse = ((pred_series - mte_truth) ** 2).mean()
print('The Mean Squared Error (MSE) of the forecast is {}'.format(round(mse, 2)))
print('The Root Mean Square Error (RMSE) of the forcast: {}'
      .format(np.sqrt(sum((pred_series - mte_truth)**2)/len(mte_forecast))))
# Out:
# The Mean Squared Error (MSE) of the forecast is 3069.38
# The Root Mean Square Error (RMSE) of the forcast: [54.33028713]

# %%
DCNN_rmse = np.sqrt(mse)

# %% [markdown]
# # LSTM

# %%
import math

# %%
ap = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/z.csv",usecols=[1])

# %%
ap=ap.dropna()
ap.shape
# Out:
# (2820, 1)

# %%
plt.figure(figsize = (15, 5))
plt.plot(ap, label = "Sunspots Dataset")
plt.xlabel("Months")
plt.ylabel("Sunspots")
plt.title("Sunspots Dataset")
plt.legend()
plt.show()

# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

# %%
ap = ap.values.astype("float32")
type(ap)
# Out:
# numpy.ndarray

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
ap_scaled = scaler.fit_transform(ap)
type(ap_scaled)
len(ap_scaled)
# Out:
# 2820

# %%
train_size = 2299
test_size = len(ap_scaled) - train_size
train, test = ap_scaled[0:train_size, :], ap_scaled[train_size:len(ap_scaled), :]
print("Number of entries (training set, test set): " + str((len(train), len(test))))
# Out:
# Number of entries (training set, test set): (2299, 521)

# %%
def create_dataset(dataset, window_size = 1):
    data_X = dataset[:(len(dataset) - window_size)]
    data_Y = np.roll(dataset, -1)[:-1]
    return(data_X, data_Y.reshape(len(data_Y),))

# %%
window_size = 1
train_X, train_Y = create_dataset(train, window_size)
test_X, test_Y = create_dataset(test, window_size)
print("Original training data shape:")
print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# Original training data shape:
# (2298, 1)
# (2298,)
# (520, 1)
# (520,)

# %%
# Reshape the input data into appropriate form for Keras.
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))
print("New training data shape:")
print(train_X.shape)
print(test_X.shape)
# Out:
# New training data shape:
# (2298, 1, 1)
# (520, 1, 1)

# %%
def fit_model(train_X, train_Y, window_size = 1):
    model = Sequential()
    
    model.add(LSTM(5, 
                   input_shape = (1, window_size)))
    model.add(Dense(1))
    model.compile(loss = "mean_squared_error", 
                  optimizer = "adam")
    model.fit(train_X, 
              train_Y, 
              epochs = 10, 
              batch_size = 1, 
              verbose = 2)
    
    return(model)

# %%
model_ap = fit_model(train_X, train_Y, window_size)
# Out:
# Epoch 1/10
#  - 8s - loss: 0.0107
# Epoch 2/10
#  - 5s - loss: 0.0042
# Epoch 3/10
#  - 5s - loss: 0.0041
# Epoch 4/10
#  - 5s - loss: 0.0042
# Epoch 5/10
#  - 5s - loss: 0.0041
# Epoch 6/10
#  - 5s - loss: 0.0041
# Epoch 7/10
#  - 5s - loss: 0.0041
# Epoch 8/10
#  - 5s - loss: 0.0041
# Epoch 9/10
#  - 5s - loss: 0.0041
# Epoch 10/10
#  - 5s - loss: 0.0041

# %%
def predict_and_score(model, X, Y):
    # Make predictions on the original scale of the data.
    pred = scaler.inverse_transform(model.predict(X))
    # Prepare Y data to also be on the original scale for interpretability.
    orig_data = scaler.inverse_transform([Y])
    # Calculate RMSE.
    score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    return(score, pred)

rmse_train, train_predict = predict_and_score(model_ap, train_X, train_Y)
rmse_test, test_predict = predict_and_score(model_ap, test_X, test_Y)

print("Training data score: %.2f RMSE" % rmse_train)
print("Test data score: %.2f RMSE" % rmse_test)
# Out:
# Training data score: 16.35 RMSE
# Test data score: 20.89 RMSE

# %%
LSTM_rmse = rmse_test

# %%
# Start with training predictions.
train_predict_plot = np.empty_like(ap_scaled)
train_predict_plot[:, :] = np.nan
train_predict_plot[window_size:len(train_predict) + window_size, :] = train_predict

# Add test predictions.
test_predict_plot = np.empty_like(ap_scaled)
test_predict_plot[:, :] = np.nan
test_predict_plot[len(train_predict) + window_size:len(ap_scaled) - 1, :] = test_predict
# Create the plot.
plt.figure(figsize = (15, 5))
plt.plot(scaler.inverse_transform(ap_scaled), label = "True value")
plt.plot(train_predict_plot, label = "Training set prediction")
plt.plot(test_predict_plot, label = "Test set prediction")
plt.xlabel("Months")
plt.ylabel("Sunspots")
plt.title("Comparison true vs. predicted training / test")
plt.legend()
plt.show()

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error
import imageio
import os
from statsmodels.graphics.tsaplots import plot_acf

# %%
df1 = pd.read_csv("E:/MS-ISE/3rd Semester/Machine Learning and Statistical Pattern Recognition/Project/z.csv",index_col=[0])
df1.head()
# Out:
#          Sunspot
# Month
# 1749-01     58.0
# 1749-02     62.6
# 1749-03     70.0
# 1749-04     55.7
# 1749-05     85.0

# %%
df1.isna().sum()
# Out:
# Sunspot    0
# dtype: int64

# %%
df1 = df1.dropna()

df1.reset_index(inplace=True)

df1['Month'] = pd.to_datetime(df1['Month'])

df1 = df1.set_index('Month')

# %%
def split_data(data, split_date):
    return data[data.index <= split_date].copy(), \
           data[data.index >  split_date].copy()

# %%
train, test = split_data(df1,'1942-02')

plt.figure(figsize=(15,5))
plt.xlabel('Time(in years)')
plt.ylabel('Sunspots')
plt.plot(train.index,train)
plt.plot(test.index,test)
plt.show()

# %%
train.iloc[:,0].shape
# Out:
# (2318,)

# %%
import statsmodels
result = statsmodels.tsa.seasonal.seasonal_decompose(df1)

# %%
plt.plot(result.trend)

# %%
def create_features(df):
    df['date'] = df.index
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    

    df['seasonal'] = result.seasonal
    df['trend'] = result.trend
    X = df[['year','month','seasonal','trend']]

    return X

# %%
X_train, y_train = create_features(train), train.iloc[:,0]
X_test, y_test   = create_features(test), test.iloc[:,0]

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2318, 4), (2318,), (502, 4), (502,))

# %%
import xgboost as xgb


# define eval metrics
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))



params = {"objective": "reg:linear", # for linear regression
          "booster" : "gbtree",   # use tree based models 
          "eta": 0.75,   # learning rate
          "max_depth": 3,    # maximum depth of a tree
          "subsample": 0.9,    # Subsample ratio of the training instances
          "colsample_bytree": 0.7,   # Subsample ratio of columns when constructing each tree
          "silent": 1,   # silent mode
          "seed": 21,   # Random number seed
          "base_score": 0.5
          }
num_boost_round = 4000

dtrain = xgb.DMatrix(X_train, y_train)
dvalid = xgb.DMatrix(X_test, y_test)
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
# train the xgboost model
model = xgb.train(params, dtrain, num_boost_round,evals=watchlist, \
  early_stopping_rounds= 1000, verbose_eval=True)
# Out:
# [0]	train-rmse:35.4516	eval-rmse:74.2923
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 1000 rounds.
# [1]	train-rmse:18.8666	eval-rmse:41.8533
# [2]	train-rmse:15.9692	eval-rmse:30.1963
# [3]	train-rmse:15.1892	eval-rmse:29.697
# [4]	train-rmse:14.5749	eval-rmse:23.3898
# [5]	train-rmse:13.9808	eval-rmse:23.5763
# [6]	train-rmse:13.8639	eval-rmse:23.796
# [7]	train-rmse:13.6413	eval-rmse:19.6806
# [8]	train-rmse:13.5425	eval-rmse:19.4702
# [9]	train-rmse:13.3076	eval-rmse:19.208
# [10]	train-rmse:13.1654	eval-rmse:19.1724
# [11]	train-rmse:13.0203	eval-rmse:18.4443
# [12]	train-rmse:12.9467	eval-rmse:18.3031
# [13]	train-rmse:12.8691	eval-rmse:18.3033
# [14]	train-rmse:12.7603	eval-rmse:18.4425
# [15]	train-rmse:12.7269	eval-rmse:18.9574
# [16]	train-rmse:12.6474	eval-rmse:20.0183
# [17]	train-rmse:12.5392	eval-rmse:20.0114
# [18]	train-rmse:12.5312	eval-rmse:20.0638
# [19]	train-rmse:12.4329	eval-rmse:20.069
# [20]	train-rmse:12.3598	eval-rmse:20.5099
# [21]	train-rmse:12.3187	eval-rmse:20.5267
# [22]	train-rmse:12.3199	eval-rmse:20.4882
# [23]	train-rmse:12.2552	eval-rmse:20.6529
# [24]	train-rmse:12.1105	eval-rmse:20.6795
# [25]	train-rmse:12.0688	eval-rmse:20.8486
# [26]	train-rmse:12.0401	eval-rmse:20.8421
# [27]	train-rmse:11.9822	eval-rmse:20.8078
# [28]	train-rmse:11.9326	eval-rmse:20.8202
# [29]	train-rmse:11.9325	eval-rmse:20.8359
# [30]	train-rmse:11.8669	eval-rmse:21.4716
# [31]	train-rmse:11.8041	eval-rmse:21.3789
# [32]	train-rmse:11.7553	eval-rmse:21.6563
# [33]	train-rmse:11.7147	eval-rmse:21.5495
# [34]	train-rmse:11.6603	eval-rmse:21.5474
# [35]	train-rmse:11.6583	eval-rmse:21.5207
# [36]	train-rmse:11.6093	eval-rmse:21.4867
# [37]	train-rmse:11.6092	eval-rmse:21.5093
# [38]	train-rmse:11.5007	eval-rmse:21.6838
# [39]	train-rmse:11.491	eval-rmse:21.6603
# [40]	train-rmse:11.4578	eval-rmse:21.8139
# [41]	train-rmse:11.361	eval-rmse:21.8872
# [42]	train-rmse:11.3328	eval-rmse:21.8531
# [43]	train-rmse:11.3346	eval-rmse:21.8326
# [44]	train-rmse:11.3052	eval-rmse:21.8915
# [45]	train-rmse:11.2998	eval-rmse:21.9451
# [46]	train-rmse:11.2763	eval-rmse:21.8652
# [47]	train-rmse:11.2739	eval-rmse:21.866
# [48]	train-rmse:11.2313	eval-rmse:21.9022
# [49]	train-rmse:11.1599	eval-rmse:22.0129
# [50]	train-rmse:11.1315	eval-rmse:22.0368
# [51]	train-rmse:11.1281	eval-rmse:22.0812
# [52]	train-rmse:11.0695	eval-rmse:22.3658
# [53]	train-rmse:11.0692	eval-rmse:22.3195
# [54]	train-rmse:11.034	eval-rmse:22.1648
# [55]	train-rmse:10.971	eval-rmse:22.1163
# [56]	train-rmse:10.9612	eval-rmse:22.1324
# [57]	train-rmse:10.9414	eval-rmse:22.1876
# [58]	train-rmse:10.8921	eval-rmse:22.5527
# [59]	train-rmse:10.8733	eval-rmse:22.709
# [60]	train-rmse:10.8529	eval-rmse:22.5533
# [61]	train-rmse:10.8328	eval-rmse:22.5709
# [62]	train-rmse:10.8112	eval-rmse:22.5917
# [63]	train-rmse:10.7955	eval-rmse:22.42
# [64]	train-rmse:10.7676	eval-rmse:22.8986
# [65]	train-rmse:10.7638	eval-rmse:22.9533
# [66]	train-rmse:10.7186	eval-rmse:22.9272
# [67]	train-rmse:10.6759	eval-rmse:23.1997
# [68]	train-rmse:10.6752	eval-rmse:23.2007
# [69]	train-rmse:10.5907	eval-rmse:23.2395
# [70]	train-rmse:10.5378	eval-rmse:23.6854
# [71]	train-rmse:10.5034	eval-rmse:23.4695
# [72]	train-rmse:10.4758	eval-rmse:23.4611
# [73]	train-rmse:10.4755	eval-rmse:23.4693
# [74]	train-rmse:10.4366	eval-rmse:23.4638
# [75]	train-rmse:10.4331	eval-rmse:23.507
# [76]	train-rmse:10.4198	eval-rmse:23.5198
# [77]	train-rmse:10.4164	eval-rmse:23.4747
# [78]	train-rmse:10.3735	eval-rmse:23.3361
# [79]	train-rmse:10.3156	eval-rmse:23.0649
# [80]	train-rmse:10.2854	eval-rmse:23.0222
# [81]	train-rmse:10.2576	eval-rmse:22.9805
# [82]	train-rmse:10.2224	eval-rmse:22.9064
# [83]	train-rmse:10.2234	eval-rmse:22.9739
# [84]	train-rmse:10.2052	eval-rmse:23.0997
# [85]	train-rmse:10.1839	eval-rmse:22.8958
# [86]	train-rmse:10.1442	eval-rmse:22.8892
# [87]	train-rmse:10.124	eval-rmse:23.1043
# [88]	train-rmse:10.0695	eval-rmse:23.1417
# [89]	train-rmse:10.0612	eval-rmse:23.1346
# [90]	train-rmse:10.0234	eval-rmse:23.143
# [91]	train-rmse:10.009	eval-rmse:23.1767
# [92]	train-rmse:9.97488	eval-rmse:23.2083
# [93]	train-rmse:9.96049	eval-rmse:23.2422
# [94]	train-rmse:9.96098	eval-rmse:23.1822
# [95]	train-rmse:9.95442	eval-rmse:23.5438
# [96]	train-rmse:9.92023	eval-rmse:23.1834
# [97]	train-rmse:9.90039	eval-rmse:23.2318
# [98]	train-rmse:9.85844	eval-rmse:23.2073
# [99]	train-rmse:9.83314	eval-rmse:23.2703
# [100]	train-rmse:9.81223	eval-rmse:23.1556
# [101]	train-rmse:9.75015	eval-rmse:22.9755
# [102]	train-rmse:9.66757	eval-rmse:22.9651
# [103]	train-rmse:9.59798	eval-rmse:22.9974
# [104]	train-rmse:9.54865	eval-rmse:23.0982
# [105]	train-rmse:9.53542	eval-rmse:23.2653
# [106]	train-rmse:9.50264	eval-rmse:23.2784
# [107]	train-rmse:9.47477	eval-rmse:23.2849
# [108]	train-rmse:9.435	eval-rmse:23.5341
# [109]	train-rmse:9.40943	eval-rmse:23.5626
# [110]	train-rmse:9.40375	eval-rmse:23.5705
# [111]	train-rmse:9.35676	eval-rmse:23.5701
# [112]	train-rmse:9.30749	eval-rmse:23.6057
# [113]	train-rmse:9.30644	eval-rmse:23.613
# [114]	train-rmse:9.30015	eval-rmse:23.5903
# [115]	train-rmse:9.29499	eval-rmse:23.581
# [116]	train-rmse:9.29358	eval-rmse:23.4362
# [117]	train-rmse:9.25281	eval-rmse:23.3795
# [118]	train-rmse:9.19686	eval-rmse:23.4098
# [119]	train-rmse:9.18276	eval-rmse:23.453
# [120]	train-rmse:9.15346	eval-rmse:23.3655
# [121]	train-rmse:9.12577	eval-rmse:23.4077
# [122]	train-rmse:9.09701	eval-rmse:23.3737
# [123]	train-rmse:9.08428	eval-rmse:23.3949
# [124]	train-rmse:9.02985	eval-rmse:23.3649
# [125]	train-rmse:8.98515	eval-rmse:23.3426
# [126]	train-rmse:8.96227	eval-rmse:23.3881
# [127]	train-rmse:8.9345	eval-rmse:23.4021
# [128]	train-rmse:8.93437	eval-rmse:23.4249
# [129]	train-rmse:8.93448	eval-rmse:23.4419
# [130]	train-rmse:8.92276	eval-rmse:23.4483
# [131]	train-rmse:8.90951	eval-rmse:23.4665
# [132]	train-rmse:8.86643	eval-rmse:23.5013
# [133]	train-rmse:8.84446	eval-rmse:23.4566
# [134]	train-rmse:8.83104	eval-rmse:23.4355
# [135]	train-rmse:8.80439	eval-rmse:23.6493
# [136]	train-rmse:8.75401	eval-rmse:23.8198
# [137]	train-rmse:8.73349	eval-rmse:23.8081
# [138]	train-rmse:8.72566	eval-rmse:23.6293
# [139]	train-rmse:8.72483	eval-rmse:23.6273
# [140]	train-rmse:8.69273	eval-rmse:23.6588
# [141]	train-rmse:8.6823	eval-rmse:23.6443
# [142]	train-rmse:8.67522	eval-rmse:23.6112
# [143]	train-rmse:8.65697	eval-rmse:23.6375
# [144]	train-rmse:8.65591	eval-rmse:23.2981
# [145]	train-rmse:8.6167	eval-rmse:23.2839
# [146]	train-rmse:8.61563	eval-rmse:23.2993
# [147]	train-rmse:8.59495	eval-rmse:23.3503
# [148]	train-rmse:8.58525	eval-rmse:23.5464
# [149]	train-rmse:8.5754	eval-rmse:23.5937
# [150]	train-rmse:8.55185	eval-rmse:23.5384
# [151]	train-rmse:8.52835	eval-rmse:23.5673
# [152]	train-rmse:8.49288	eval-rmse:23.5739
# [153]	train-rmse:8.4712	eval-rmse:23.621
# [154]	train-rmse:8.45967	eval-rmse:23.8363
# [155]	train-rmse:8.45375	eval-rmse:23.9041
# [156]	train-rmse:8.44401	eval-rmse:23.9005
# [157]	train-rmse:8.44425	eval-rmse:23.927
# [158]	train-rmse:8.43042	eval-rmse:23.6335
# [159]	train-rmse:8.40876	eval-rmse:23.5795
# [160]	train-rmse:8.402	eval-rmse:23.6237
# [161]	train-rmse:8.39498	eval-rmse:23.5863
# [162]	train-rmse:8.38889	eval-rmse:23.5896
# [163]	train-rmse:8.365	eval-rmse:23.5927
# [164]	train-rmse:8.35743	eval-rmse:23.582
# [165]	train-rmse:8.32303	eval-rmse:23.4927
# [166]	train-rmse:8.30875	eval-rmse:23.5027
# [167]	train-rmse:8.27274	eval-rmse:23.4996
# [168]	train-rmse:8.26308	eval-rmse:23.4123
# [169]	train-rmse:8.26155	eval-rmse:23.4219
# [170]	train-rmse:8.2356	eval-rmse:23.5555
# [171]	train-rmse:8.22444	eval-rmse:23.6528
# [172]	train-rmse:8.1804	eval-rmse:23.6771
# [173]	train-rmse:8.17891	eval-rmse:23.6889
# [174]	train-rmse:8.15521	eval-rmse:23.666
# [175]	train-rmse:8.11191	eval-rmse:23.5996
# [176]	train-rmse:8.1047	eval-rmse:23.7574
# [177]	train-rmse:8.1047	eval-rmse:23.7503
# [178]	train-rmse:8.08295	eval-rmse:23.6239
# [179]	train-rmse:8.0764	eval-rmse:23.6326
# [180]	train-rmse:8.06244	eval-rmse:23.5625
# [181]	train-rmse:8.02239	eval-rmse:23.5385
# [182]	train-rmse:8.01624	eval-rmse:23.5581
# [183]	train-rmse:7.98011	eval-rmse:23.5217
# [184]	train-rmse:7.96723	eval-rmse:23.582
# [185]	train-rmse:7.96769	eval-rmse:23.5927
# [186]	train-rmse:7.9676	eval-rmse:23.5755
# [187]	train-rmse:7.95934	eval-rmse:23.6054
# [188]	train-rmse:7.94514	eval-rmse:23.6139
# [189]	train-rmse:7.93923	eval-rmse:23.5174
# [190]	train-rmse:7.93956	eval-rmse:23.5368
# [191]	train-rmse:7.92962	eval-rmse:23.5416
# [192]	train-rmse:7.92867	eval-rmse:23.5285
# [193]	train-rmse:7.88331	eval-rmse:23.5646
# [194]	train-rmse:7.84883	eval-rmse:23.5693
# [195]	train-rmse:7.84299	eval-rmse:23.553
# [196]	train-rmse:7.84337	eval-rmse:23.5563
# [197]	train-rmse:7.83119	eval-rmse:23.5425
# [198]	train-rmse:7.81122	eval-rmse:23.5301
# [199]	train-rmse:7.79633	eval-rmse:23.5509
# [200]	train-rmse:7.79702	eval-rmse:23.5588
# [201]	train-rmse:7.79729	eval-rmse:23.5488
# [202]	train-rmse:7.77722	eval-rmse:23.6001
# [203]	train-rmse:7.76586	eval-rmse:23.5885
# [204]	train-rmse:7.72587	eval-rmse:23.5707
# [205]	train-rmse:7.69052	eval-rmse:23.5681
# [206]	train-rmse:7.64846	eval-rmse:23.5346
# [207]	train-rmse:7.6332	eval-rmse:23.4156
# [208]	train-rmse:7.60574	eval-rmse:23.3724
# [209]	train-rmse:7.59435	eval-rmse:23.3515
# [210]	train-rmse:7.56932	eval-rmse:23.4018
# [211]	train-rmse:7.57071	eval-rmse:23.3871
# [212]	train-rmse:7.55742	eval-rmse:23.4187
# [213]	train-rmse:7.5313	eval-rmse:23.4176
# [214]	train-rmse:7.50841	eval-rmse:23.42
# [215]	train-rmse:7.49735	eval-rmse:23.3142
# [216]	train-rmse:7.49154	eval-rmse:23.3414
# [217]	train-rmse:7.47072	eval-rmse:23.1197
# [218]	train-rmse:7.46953	eval-rmse:23.1187
# [219]	train-rmse:7.45837	eval-rmse:23.1476
# [220]	train-rmse:7.45059	eval-rmse:23.1303
# [221]	train-rmse:7.43053	eval-rmse:23.1096
# [222]	train-rmse:7.41491	eval-rmse:23.1208
# [223]	train-rmse:7.40795	eval-rmse:23.1824
# [224]	train-rmse:7.40644	eval-rmse:23.1819
# [225]	train-rmse:7.40057	eval-rmse:23.4371
# [226]	train-rmse:7.39284	eval-rmse:23.4545
# [227]	train-rmse:7.38719	eval-rmse:23.4528
# [228]	train-rmse:7.3878	eval-rmse:23.4473
# [229]	train-rmse:7.3704	eval-rmse:23.4581
# [230]	train-rmse:7.36395	eval-rmse:23.4542
# [231]	train-rmse:7.34512	eval-rmse:23.469
# [232]	train-rmse:7.33776	eval-rmse:23.5045
# [233]	train-rmse:7.32359	eval-rmse:23.4919
# [234]	train-rmse:7.31402	eval-rmse:23.4222
# [235]	train-rmse:7.30668	eval-rmse:23.4128
# [236]	train-rmse:7.29857	eval-rmse:23.4175
# [237]	train-rmse:7.27869	eval-rmse:23.3979
# [238]	train-rmse:7.27435	eval-rmse:23.3911
# [239]	train-rmse:7.25861	eval-rmse:23.3995
# [240]	train-rmse:7.23518	eval-rmse:23.4089
# [241]	train-rmse:7.21913	eval-rmse:23.4294
# [242]	train-rmse:7.21818	eval-rmse:23.4619
# [243]	train-rmse:7.21458	eval-rmse:23.4291
# [244]	train-rmse:7.209	eval-rmse:23.42
# [245]	train-rmse:7.20886	eval-rmse:23.4184
# [246]	train-rmse:7.208	eval-rmse:23.4562
# [247]	train-rmse:7.20083	eval-rmse:23.4559
# [248]	train-rmse:7.16237	eval-rmse:23.4657
# [249]	train-rmse:7.15159	eval-rmse:23.4778
# [250]	train-rmse:7.13613	eval-rmse:23.457
# [251]	train-rmse:7.13575	eval-rmse:23.4718
# [252]	train-rmse:7.13716	eval-rmse:23.4773
# [253]	train-rmse:7.10533	eval-rmse:23.5051
# [254]	train-rmse:7.09663	eval-rmse:23.5166
# [255]	train-rmse:7.08926	eval-rmse:23.5129
# [256]	train-rmse:7.08885	eval-rmse:23.5243
# [257]	train-rmse:7.06056	eval-rmse:23.522
# [258]	train-rmse:7.03455	eval-rmse:23.5399
# [259]	train-rmse:7.02585	eval-rmse:23.5299
# [260]	train-rmse:7.0119	eval-rmse:23.5637
# [261]	train-rmse:7.00161	eval-rmse:23.6174
# [262]	train-rmse:6.99078	eval-rmse:23.6175
# [263]	train-rmse:6.96329	eval-rmse:23.6219
# [264]	train-rmse:6.9415	eval-rmse:23.6208
# [265]	train-rmse:6.93001	eval-rmse:23.58
# [266]	train-rmse:6.92581	eval-rmse:23.5885
# [267]	train-rmse:6.92256	eval-rmse:23.665
# [268]	train-rmse:6.918	eval-rmse:23.6848
# [269]	train-rmse:6.90221	eval-rmse:23.798
# [270]	train-rmse:6.89586	eval-rmse:23.779
# [271]	train-rmse:6.88272	eval-rmse:23.7764
# [272]	train-rmse:6.87436	eval-rmse:23.7397
# [273]	train-rmse:6.84413	eval-rmse:23.7329
# [274]	train-rmse:6.84478	eval-rmse:23.7317
# [275]	train-rmse:6.84383	eval-rmse:23.7377
# [276]	train-rmse:6.82743	eval-rmse:23.7252
# [277]	train-rmse:6.81498	eval-rmse:23.7848
# [278]	train-rmse:6.79117	eval-rmse:23.7911
# [279]	train-rmse:6.78603	eval-rmse:23.6579
# [280]	train-rmse:6.77576	eval-rmse:23.6711
# [281]	train-rmse:6.76179	eval-rmse:23.6585
# [282]	train-rmse:6.74423	eval-rmse:23.6381
# [283]	train-rmse:6.74173	eval-rmse:23.9073
# [284]	train-rmse:6.73038	eval-rmse:23.9552
# [285]	train-rmse:6.72608	eval-rmse:23.9531
# [286]	train-rmse:6.71723	eval-rmse:23.9658
# [287]	train-rmse:6.71024	eval-rmse:23.9626
# [288]	train-rmse:6.70205	eval-rmse:23.9949
# [289]	train-rmse:6.66698	eval-rmse:24.024
# [290]	train-rmse:6.66108	eval-rmse:24.0219
# [291]	train-rmse:6.64419	eval-rmse:24.0315
# [292]	train-rmse:6.631	eval-rmse:24.1107
# [293]	train-rmse:6.62614	eval-rmse:24.116
# [294]	train-rmse:6.61874	eval-rmse:24.1009
# [295]	train-rmse:6.60748	eval-rmse:24.0446
# [296]	train-rmse:6.59835	eval-rmse:24.0318
# [297]	train-rmse:6.5987	eval-rmse:24.0418
# [298]	train-rmse:6.58745	eval-rmse:24.0229
# [299]	train-rmse:6.57325	eval-rmse:24.0631
# [300]	train-rmse:6.55752	eval-rmse:24.07
# [301]	train-rmse:6.54533	eval-rmse:24.0596
# [302]	train-rmse:6.5349	eval-rmse:24.0588
# [303]	train-rmse:6.51376	eval-rmse:24.0632
# [304]	train-rmse:6.50655	eval-rmse:24.073
# [305]	train-rmse:6.49671	eval-rmse:24.0545
# [306]	train-rmse:6.48765	eval-rmse:24.0665
# [307]	train-rmse:6.4873	eval-rmse:24.0775
# [308]	train-rmse:6.45418	eval-rmse:24.1008
# [309]	train-rmse:6.42757	eval-rmse:24.0949
# [310]	train-rmse:6.42162	eval-rmse:24.0526
# [311]	train-rmse:6.41084	eval-rmse:24.0565
# [312]	train-rmse:6.39167	eval-rmse:23.9747
# [313]	train-rmse:6.39121	eval-rmse:23.9762
# [314]	train-rmse:6.38183	eval-rmse:23.9843
# [315]	train-rmse:6.36046	eval-rmse:23.9811
# [316]	train-rmse:6.35349	eval-rmse:23.9776
# [317]	train-rmse:6.33403	eval-rmse:23.963
# [318]	train-rmse:6.32826	eval-rmse:23.9607
# [319]	train-rmse:6.3282	eval-rmse:23.9709
# [320]	train-rmse:6.32422	eval-rmse:23.9738
# [321]	train-rmse:6.32551	eval-rmse:23.9612
# [322]	train-rmse:6.3179	eval-rmse:24.0268
# [323]	train-rmse:6.30828	eval-rmse:24.0519
# [324]	train-rmse:6.30174	eval-rmse:23.9946
# [325]	train-rmse:6.2828	eval-rmse:23.9911
# [326]	train-rmse:6.28026	eval-rmse:23.9556
# [327]	train-rmse:6.2641	eval-rmse:23.9426
# [328]	train-rmse:6.24394	eval-rmse:23.9527
# [329]	train-rmse:6.21544	eval-rmse:23.9594
# [330]	train-rmse:6.20599	eval-rmse:23.9577
# [331]	train-rmse:6.17962	eval-rmse:23.9683
# [332]	train-rmse:6.17936	eval-rmse:23.9948
# [333]	train-rmse:6.17321	eval-rmse:24.0093
# [334]	train-rmse:6.15084	eval-rmse:24.0359
# [335]	train-rmse:6.14968	eval-rmse:24.0441
# [336]	train-rmse:6.14452	eval-rmse:23.9934
# [337]	train-rmse:6.1448	eval-rmse:23.9895
# [338]	train-rmse:6.14399	eval-rmse:23.9984
# [339]	train-rmse:6.13915	eval-rmse:24.0164
# [340]	train-rmse:6.13764	eval-rmse:24.034
# [341]	train-rmse:6.13537	eval-rmse:24.0363
# [342]	train-rmse:6.11082	eval-rmse:24.0464
# [343]	train-rmse:6.10166	eval-rmse:24.0407
# [344]	train-rmse:6.07576	eval-rmse:24.037
# [345]	train-rmse:6.07518	eval-rmse:24.0105
# [346]	train-rmse:6.06055	eval-rmse:24.0009
# [347]	train-rmse:6.05084	eval-rmse:23.9976
# [348]	train-rmse:6.03196	eval-rmse:24.0051
# [349]	train-rmse:6.02318	eval-rmse:24.0026
# [350]	train-rmse:6.0154	eval-rmse:23.9623
# [351]	train-rmse:6.00831	eval-rmse:24.0269
# [352]	train-rmse:6.00246	eval-rmse:24.0896
# [353]	train-rmse:6.00289	eval-rmse:24.1061
# [354]	train-rmse:5.99383	eval-rmse:24.0923
# [355]	train-rmse:5.97587	eval-rmse:24.1119
# [356]	train-rmse:5.96957	eval-rmse:24.1607
# [357]	train-rmse:5.96088	eval-rmse:24.1339
# [358]	train-rmse:5.93396	eval-rmse:24.1231
# [359]	train-rmse:5.93058	eval-rmse:24.1057
# [360]	train-rmse:5.92535	eval-rmse:24.162
# [361]	train-rmse:5.92189	eval-rmse:24.3237
# [362]	train-rmse:5.91893	eval-rmse:24.329
# [363]	train-rmse:5.91449	eval-rmse:24.332
# [364]	train-rmse:5.91435	eval-rmse:24.3241
# [365]	train-rmse:5.88262	eval-rmse:24.3294
# [366]	train-rmse:5.86439	eval-rmse:24.3313
# [367]	train-rmse:5.85909	eval-rmse:24.3275
# [368]	train-rmse:5.8585	eval-rmse:24.2728
# [369]	train-rmse:5.85067	eval-rmse:24.2663
# [370]	train-rmse:5.84783	eval-rmse:24.266
# [371]	train-rmse:5.82983	eval-rmse:24.263
# [372]	train-rmse:5.82995	eval-rmse:24.2691
# [373]	train-rmse:5.82693	eval-rmse:24.2798
# [374]	train-rmse:5.82397	eval-rmse:24.2737
# [375]	train-rmse:5.81697	eval-rmse:24.2739
# [376]	train-rmse:5.81259	eval-rmse:24.25
# [377]	train-rmse:5.81371	eval-rmse:24.2503
# [378]	train-rmse:5.80143	eval-rmse:24.2515
# [379]	train-rmse:5.79792	eval-rmse:24.2523
# [380]	train-rmse:5.78386	eval-rmse:24.2668
# [381]	train-rmse:5.77316	eval-rmse:24.2666
# [382]	train-rmse:5.76817	eval-rmse:24.2673
# [383]	train-rmse:5.7596	eval-rmse:24.2603
# [384]	train-rmse:5.74679	eval-rmse:24.2952
# [385]	train-rmse:5.7427	eval-rmse:24.2474
# [386]	train-rmse:5.7331	eval-rmse:24.2547
# [387]	train-rmse:5.71984	eval-rmse:24.2161
# [388]	train-rmse:5.71639	eval-rmse:24.2671
# [389]	train-rmse:5.71702	eval-rmse:24.287
# [390]	train-rmse:5.71604	eval-rmse:24.3022
# [391]	train-rmse:5.70592	eval-rmse:24.3075
# [392]	train-rmse:5.70041	eval-rmse:24.2951
# [393]	train-rmse:5.69991	eval-rmse:24.2984
# [394]	train-rmse:5.69182	eval-rmse:24.3114
# [395]	train-rmse:5.67287	eval-rmse:24.2895
# [396]	train-rmse:5.65747	eval-rmse:24.2988
# [397]	train-rmse:5.65379	eval-rmse:24.2932
# [398]	train-rmse:5.64393	eval-rmse:24.2907
# [399]	train-rmse:5.6265	eval-rmse:24.2977
# [400]	train-rmse:5.61686	eval-rmse:24.2911
# [401]	train-rmse:5.60914	eval-rmse:24.2785
# [402]	train-rmse:5.60297	eval-rmse:24.2647
# [403]	train-rmse:5.59101	eval-rmse:24.2693
# [404]	train-rmse:5.57519	eval-rmse:24.272
# [405]	train-rmse:5.57016	eval-rmse:24.1684
# [406]	train-rmse:5.55591	eval-rmse:24.1568
# [407]	train-rmse:5.55618	eval-rmse:24.1613
# [408]	train-rmse:5.54809	eval-rmse:24.1608
# [409]	train-rmse:5.54865	eval-rmse:24.171
# [410]	train-rmse:5.54809	eval-rmse:24.1661
# [411]	train-rmse:5.54466	eval-rmse:24.1673
# [412]	train-rmse:5.53768	eval-rmse:24.1624
# [413]	train-rmse:5.52487	eval-rmse:24.172
# [414]	train-rmse:5.51272	eval-rmse:24.1944
# [415]	train-rmse:5.50236	eval-rmse:24.1961
# [416]	train-rmse:5.49529	eval-rmse:24.1975
# [417]	train-rmse:5.48642	eval-rmse:24.1941
# [418]	train-rmse:5.48695	eval-rmse:24.1896
# [419]	train-rmse:5.47379	eval-rmse:24.1893
# [420]	train-rmse:5.47377	eval-rmse:24.2049
# [421]	train-rmse:5.45331	eval-rmse:24.1771
# [422]	train-rmse:5.43773	eval-rmse:24.1687
# [423]	train-rmse:5.42587	eval-rmse:24.1673
# [424]	train-rmse:5.42587	eval-rmse:24.1759
# [425]	train-rmse:5.42628	eval-rmse:24.1718
# [426]	train-rmse:5.42452	eval-rmse:24.1749
# [427]	train-rmse:5.40702	eval-rmse:24.1762
# [428]	train-rmse:5.40176	eval-rmse:24.2118
# [429]	train-rmse:5.40214	eval-rmse:24.2121
# [430]	train-rmse:5.39135	eval-rmse:24.2085
# [431]	train-rmse:5.36117	eval-rmse:24.2023
# [432]	train-rmse:5.35388	eval-rmse:24.1904
# [433]	train-rmse:5.34803	eval-rmse:24.1865
# [434]	train-rmse:5.3418	eval-rmse:24.2685
# [435]	train-rmse:5.3373	eval-rmse:24.2318
# [436]	train-rmse:5.33075	eval-rmse:24.2188
# [437]	train-rmse:5.32697	eval-rmse:24.2151
# [438]	train-rmse:5.31336	eval-rmse:24.2367
# [439]	train-rmse:5.30746	eval-rmse:24.2561
# [440]	train-rmse:5.29626	eval-rmse:24.2521
# [441]	train-rmse:5.29606	eval-rmse:24.2467
# [442]	train-rmse:5.28212	eval-rmse:24.2615
# [443]	train-rmse:5.2638	eval-rmse:24.2601
# [444]	train-rmse:5.25371	eval-rmse:24.2501
# [445]	train-rmse:5.24386	eval-rmse:24.2398
# [446]	train-rmse:5.22543	eval-rmse:24.2478
# [447]	train-rmse:5.22536	eval-rmse:24.2543
# [448]	train-rmse:5.21988	eval-rmse:24.3098
# [449]	train-rmse:5.21734	eval-rmse:24.3105
# [450]	train-rmse:5.21521	eval-rmse:24.3397
# [451]	train-rmse:5.1979	eval-rmse:24.3562
# [452]	train-rmse:5.1862	eval-rmse:24.2676
# [453]	train-rmse:5.18079	eval-rmse:24.254
# [454]	train-rmse:5.16744	eval-rmse:24.2429
# [455]	train-rmse:5.16617	eval-rmse:24.2782
# [456]	train-rmse:5.16195	eval-rmse:24.3148
# [457]	train-rmse:5.15291	eval-rmse:24.3307
# [458]	train-rmse:5.1412	eval-rmse:24.337
# [459]	train-rmse:5.1318	eval-rmse:24.3405
# [460]	train-rmse:5.13161	eval-rmse:24.3489
# [461]	train-rmse:5.12261	eval-rmse:24.3552
# [462]	train-rmse:5.11196	eval-rmse:24.3807
# [463]	train-rmse:5.10567	eval-rmse:24.3816
# [464]	train-rmse:5.10635	eval-rmse:24.3922
# [465]	train-rmse:5.08772	eval-rmse:24.38
# [466]	train-rmse:5.07794	eval-rmse:24.3835
# [467]	train-rmse:5.07351	eval-rmse:24.3739
# [468]	train-rmse:5.06427	eval-rmse:24.3739
# [469]	train-rmse:5.06446	eval-rmse:24.3462
# [470]	train-rmse:5.06454	eval-rmse:24.3565
# [471]	train-rmse:5.06257	eval-rmse:24.3711
# [472]	train-rmse:5.05373	eval-rmse:24.3098
# [473]	train-rmse:5.0535	eval-rmse:24.3017
# [474]	train-rmse:5.03937	eval-rmse:24.2905
# [475]	train-rmse:5.03279	eval-rmse:24.3021
# [476]	train-rmse:5.01813	eval-rmse:24.2921
# [477]	train-rmse:4.9967	eval-rmse:24.2968
# [478]	train-rmse:4.9847	eval-rmse:24.2879
# [479]	train-rmse:4.98352	eval-rmse:24.2095
# [480]	train-rmse:4.98405	eval-rmse:24.235
# [481]	train-rmse:4.98359	eval-rmse:24.2254
# [482]	train-rmse:4.96969	eval-rmse:24.2419
# [483]	train-rmse:4.96645	eval-rmse:24.2442
# [484]	train-rmse:4.95202	eval-rmse:24.2491
# [485]	train-rmse:4.93932	eval-rmse:24.2651
# [486]	train-rmse:4.93304	eval-rmse:24.2553
# [487]	train-rmse:4.93295	eval-rmse:24.2431
# [488]	train-rmse:4.93199	eval-rmse:24.2258
# [489]	train-rmse:4.92961	eval-rmse:24.231
# [490]	train-rmse:4.92951	eval-rmse:24.2438
# [491]	train-rmse:4.92495	eval-rmse:24.2354
# [492]	train-rmse:4.91928	eval-rmse:24.1908
# [493]	train-rmse:4.9193	eval-rmse:24.1813
# [494]	train-rmse:4.91231	eval-rmse:24.1379
# [495]	train-rmse:4.90088	eval-rmse:24.1644
# [496]	train-rmse:4.89687	eval-rmse:24.1761
# [497]	train-rmse:4.89304	eval-rmse:24.1678
# [498]	train-rmse:4.8817	eval-rmse:24.2199
# [499]	train-rmse:4.86567	eval-rmse:24.2275
# [500]	train-rmse:4.86179	eval-rmse:24.2416
# [501]	train-rmse:4.86137	eval-rmse:24.2356
# [502]	train-rmse:4.84746	eval-rmse:24.2428
# [503]	train-rmse:4.84624	eval-rmse:24.1145
# [504]	train-rmse:4.84253	eval-rmse:24.1047
# [505]	train-rmse:4.83535	eval-rmse:24.0597
# [506]	train-rmse:4.83364	eval-rmse:24.0177
# [507]	train-rmse:4.834	eval-rmse:24.0333
# [508]	train-rmse:4.81795	eval-rmse:24.047
# [509]	train-rmse:4.818	eval-rmse:24.0346
# [510]	train-rmse:4.81467	eval-rmse:23.8902
# [511]	train-rmse:4.80666	eval-rmse:23.8896
# [512]	train-rmse:4.8069	eval-rmse:23.9021
# [513]	train-rmse:4.80263	eval-rmse:23.9223
# [514]	train-rmse:4.79439	eval-rmse:23.9311
# [515]	train-rmse:4.78524	eval-rmse:23.9311
# [516]	train-rmse:4.77219	eval-rmse:23.947
# [517]	train-rmse:4.76631	eval-rmse:23.9351
# [518]	train-rmse:4.75041	eval-rmse:23.9169
# [519]	train-rmse:4.73534	eval-rmse:23.9261
# [520]	train-rmse:4.72508	eval-rmse:23.933
# [521]	train-rmse:4.72369	eval-rmse:23.9844
# [522]	train-rmse:4.72344	eval-rmse:23.9852
# [523]	train-rmse:4.71352	eval-rmse:24.0351
# [524]	train-rmse:4.70092	eval-rmse:24.0345
# [525]	train-rmse:4.69258	eval-rmse:24.0288
# [526]	train-rmse:4.68346	eval-rmse:24.0371
# [527]	train-rmse:4.67708	eval-rmse:24.0483
# [528]	train-rmse:4.67347	eval-rmse:24.0388
# [529]	train-rmse:4.66953	eval-rmse:24.0408
# [530]	train-rmse:4.66003	eval-rmse:24.0215
# [531]	train-rmse:4.64998	eval-rmse:24.0296
# [532]	train-rmse:4.64942	eval-rmse:24.0377
# [533]	train-rmse:4.63917	eval-rmse:24.0338
# [534]	train-rmse:4.63542	eval-rmse:24.0269
# [535]	train-rmse:4.63376	eval-rmse:24.027
# [536]	train-rmse:4.63391	eval-rmse:24.0366
# [537]	train-rmse:4.63396	eval-rmse:24.0385
# [538]	train-rmse:4.62476	eval-rmse:24.0422
# [539]	train-rmse:4.62027	eval-rmse:24.0357
# [540]	train-rmse:4.61512	eval-rmse:24.0332
# [541]	train-rmse:4.5978	eval-rmse:24.0184
# [542]	train-rmse:4.5929	eval-rmse:24.0275
# [543]	train-rmse:4.56918	eval-rmse:24.0179
# [544]	train-rmse:4.56575	eval-rmse:24.0221
# [545]	train-rmse:4.56385	eval-rmse:24.0025
# [546]	train-rmse:4.56402	eval-rmse:23.9864
# [547]	train-rmse:4.5608	eval-rmse:23.984
# [548]	train-rmse:4.56174	eval-rmse:23.9901
# [549]	train-rmse:4.55228	eval-rmse:24.0072
# [550]	train-rmse:4.54627	eval-rmse:24.0066
# [551]	train-rmse:4.54184	eval-rmse:24.0026
# [552]	train-rmse:4.53895	eval-rmse:24.0263
# [553]	train-rmse:4.53836	eval-rmse:24.0315
# [554]	train-rmse:4.53266	eval-rmse:24.0314
# [555]	train-rmse:4.52823	eval-rmse:24.0428
# [556]	train-rmse:4.51477	eval-rmse:24.0312
# [557]	train-rmse:4.50958	eval-rmse:24.0334
# [558]	train-rmse:4.50995	eval-rmse:24.0376
# [559]	train-rmse:4.5035	eval-rmse:24.039
# [560]	train-rmse:4.50169	eval-rmse:24.0406
# [561]	train-rmse:4.50178	eval-rmse:24.036
# [562]	train-rmse:4.4953	eval-rmse:24.0328
# [563]	train-rmse:4.49522	eval-rmse:24.0324
# [564]	train-rmse:4.48918	eval-rmse:24.038
# [565]	train-rmse:4.48663	eval-rmse:24.0372
# [566]	train-rmse:4.47552	eval-rmse:24.0238
# [567]	train-rmse:4.47427	eval-rmse:24.0418
# [568]	train-rmse:4.47211	eval-rmse:24.0325
# [569]	train-rmse:4.46709	eval-rmse:24.0374
# [570]	train-rmse:4.45658	eval-rmse:24.0375
# [571]	train-rmse:4.44822	eval-rmse:24.0706
# [572]	train-rmse:4.44873	eval-rmse:24.0691
# [573]	train-rmse:4.44837	eval-rmse:24.067
# [574]	train-rmse:4.44045	eval-rmse:24.0582
# [575]	train-rmse:4.42288	eval-rmse:24.0608
# [576]	train-rmse:4.40508	eval-rmse:24.0459
# [577]	train-rmse:4.40078	eval-rmse:24.0455
# [578]	train-rmse:4.39484	eval-rmse:24.0341
# [579]	train-rmse:4.39498	eval-rmse:24.0461
# [580]	train-rmse:4.38634	eval-rmse:24.0729
# [581]	train-rmse:4.3796	eval-rmse:24.0751
# [582]	train-rmse:4.37941	eval-rmse:24.0672
# [583]	train-rmse:4.37936	eval-rmse:24.0773
# [584]	train-rmse:4.37427	eval-rmse:24.4532
# [585]	train-rmse:4.35864	eval-rmse:24.4405
# [586]	train-rmse:4.34636	eval-rmse:24.4508
# [587]	train-rmse:4.34663	eval-rmse:24.4334
# [588]	train-rmse:4.34241	eval-rmse:24.4356
# [589]	train-rmse:4.3395	eval-rmse:24.6603
# [590]	train-rmse:4.32516	eval-rmse:24.6506
# [591]	train-rmse:4.32317	eval-rmse:24.6529
# [592]	train-rmse:4.31456	eval-rmse:24.6621
# [593]	train-rmse:4.30962	eval-rmse:24.6204
# [594]	train-rmse:4.30464	eval-rmse:24.6188
# [595]	train-rmse:4.30488	eval-rmse:24.6371
# [596]	train-rmse:4.30167	eval-rmse:24.6711
# [597]	train-rmse:4.29737	eval-rmse:24.6912
# [598]	train-rmse:4.28517	eval-rmse:24.7014
# [599]	train-rmse:4.28474	eval-rmse:24.7025
# [600]	train-rmse:4.28498	eval-rmse:24.7035
# [601]	train-rmse:4.28354	eval-rmse:24.6444
# [602]	train-rmse:4.2802	eval-rmse:24.6554
# [603]	train-rmse:4.27399	eval-rmse:24.6559
# [604]	train-rmse:4.27009	eval-rmse:24.5672
# [605]	train-rmse:4.25918	eval-rmse:24.555
# [606]	train-rmse:4.25026	eval-rmse:24.5636
# [607]	train-rmse:4.25084	eval-rmse:24.5761
# [608]	train-rmse:4.2416	eval-rmse:24.5977
# [609]	train-rmse:4.23976	eval-rmse:24.5967
# [610]	train-rmse:4.23744	eval-rmse:24.5892
# [611]	train-rmse:4.23077	eval-rmse:24.5876
# [612]	train-rmse:4.23083	eval-rmse:24.569
# [613]	train-rmse:4.22691	eval-rmse:24.4636
# [614]	train-rmse:4.2247	eval-rmse:24.4529
# [615]	train-rmse:4.21785	eval-rmse:24.4504
# [616]	train-rmse:4.21028	eval-rmse:24.4856
# [617]	train-rmse:4.19898	eval-rmse:24.5222
# [618]	train-rmse:4.19889	eval-rmse:24.5253
# [619]	train-rmse:4.19429	eval-rmse:24.546
# [620]	train-rmse:4.19174	eval-rmse:24.406
# [621]	train-rmse:4.19223	eval-rmse:24.4147
# [622]	train-rmse:4.18844	eval-rmse:24.4104
# [623]	train-rmse:4.18079	eval-rmse:24.3795
# [624]	train-rmse:4.17728	eval-rmse:24.4313
# [625]	train-rmse:4.17392	eval-rmse:24.4546
# [626]	train-rmse:4.16713	eval-rmse:24.4253
# [627]	train-rmse:4.16164	eval-rmse:24.419
# [628]	train-rmse:4.15189	eval-rmse:24.4405
# [629]	train-rmse:4.14979	eval-rmse:24.461
# [630]	train-rmse:4.14699	eval-rmse:24.4173
# [631]	train-rmse:4.14698	eval-rmse:24.4129
# [632]	train-rmse:4.13846	eval-rmse:24.3433
# [633]	train-rmse:4.12997	eval-rmse:24.3443
# [634]	train-rmse:4.13063	eval-rmse:24.3264
# [635]	train-rmse:4.12899	eval-rmse:24.3434
# [636]	train-rmse:4.12862	eval-rmse:24.3494
# [637]	train-rmse:4.11892	eval-rmse:24.3525
# [638]	train-rmse:4.11723	eval-rmse:24.2626
# [639]	train-rmse:4.11578	eval-rmse:24.2623
# [640]	train-rmse:4.10538	eval-rmse:24.2909
# [641]	train-rmse:4.10389	eval-rmse:24.3798
# [642]	train-rmse:4.10378	eval-rmse:24.3731
# [643]	train-rmse:4.09137	eval-rmse:24.3708
# [644]	train-rmse:4.08552	eval-rmse:24.3675
# [645]	train-rmse:4.08136	eval-rmse:24.3847
# [646]	train-rmse:4.07408	eval-rmse:24.3731
# [647]	train-rmse:4.07376	eval-rmse:24.3632
# [648]	train-rmse:4.07346	eval-rmse:24.399
# [649]	train-rmse:4.0639	eval-rmse:24.4052
# [650]	train-rmse:4.06323	eval-rmse:24.4118
# [651]	train-rmse:4.06338	eval-rmse:24.412
# [652]	train-rmse:4.05317	eval-rmse:24.4245
# [653]	train-rmse:4.04336	eval-rmse:24.4213
# [654]	train-rmse:4.04113	eval-rmse:24.4242
# [655]	train-rmse:4.03676	eval-rmse:24.4001
# [656]	train-rmse:4.02847	eval-rmse:24.3949
# [657]	train-rmse:4.02248	eval-rmse:24.3622
# [658]	train-rmse:4.01269	eval-rmse:24.3287
# [659]	train-rmse:4.0129	eval-rmse:24.3209
# [660]	train-rmse:4.00827	eval-rmse:24.3262
# [661]	train-rmse:4.0088	eval-rmse:24.323
# [662]	train-rmse:4.00695	eval-rmse:24.327
# [663]	train-rmse:3.99796	eval-rmse:24.3217
# [664]	train-rmse:3.99654	eval-rmse:24.3471
# [665]	train-rmse:3.98787	eval-rmse:24.3417
# [666]	train-rmse:3.98466	eval-rmse:24.3427
# [667]	train-rmse:3.97065	eval-rmse:24.3254
# [668]	train-rmse:3.96519	eval-rmse:24.333
# [669]	train-rmse:3.95567	eval-rmse:24.3492
# [670]	train-rmse:3.94724	eval-rmse:24.3398
# [671]	train-rmse:3.93818	eval-rmse:24.3333
# [672]	train-rmse:3.93021	eval-rmse:24.3461
# [673]	train-rmse:3.92047	eval-rmse:24.3509
# [674]	train-rmse:3.91474	eval-rmse:24.3558
# [675]	train-rmse:3.90612	eval-rmse:24.3655
# [676]	train-rmse:3.90625	eval-rmse:24.3816
# [677]	train-rmse:3.90335	eval-rmse:24.3885
# [678]	train-rmse:3.90002	eval-rmse:24.358
# [679]	train-rmse:3.89624	eval-rmse:24.361
# [680]	train-rmse:3.89362	eval-rmse:24.3626
# [681]	train-rmse:3.89176	eval-rmse:24.3612
# [682]	train-rmse:3.8924	eval-rmse:24.339
# [683]	train-rmse:3.89011	eval-rmse:24.3443
# [684]	train-rmse:3.88686	eval-rmse:24.3403
# [685]	train-rmse:3.87628	eval-rmse:24.3303
# [686]	train-rmse:3.87639	eval-rmse:24.3309
# [687]	train-rmse:3.86711	eval-rmse:24.3564
# [688]	train-rmse:3.86278	eval-rmse:24.3631
# [689]	train-rmse:3.86113	eval-rmse:24.3418
# [690]	train-rmse:3.85202	eval-rmse:24.3315
# [691]	train-rmse:3.85134	eval-rmse:24.3334
# [692]	train-rmse:3.8437	eval-rmse:24.3382
# [693]	train-rmse:3.83828	eval-rmse:24.3374
# [694]	train-rmse:3.83014	eval-rmse:24.3304
# [695]	train-rmse:3.82431	eval-rmse:24.341
# [696]	train-rmse:3.82435	eval-rmse:24.3371
# [697]	train-rmse:3.8219	eval-rmse:24.3322
# [698]	train-rmse:3.82175	eval-rmse:24.3363
# [699]	train-rmse:3.81767	eval-rmse:24.3308
# [700]	train-rmse:3.81082	eval-rmse:24.3402
# [701]	train-rmse:3.80904	eval-rmse:24.3471
# [702]	train-rmse:3.80935	eval-rmse:24.3574
# [703]	train-rmse:3.80937	eval-rmse:24.3609
# [704]	train-rmse:3.80916	eval-rmse:24.3657
# [705]	train-rmse:3.80495	eval-rmse:24.3624
# [706]	train-rmse:3.80022	eval-rmse:24.3675
# [707]	train-rmse:3.79384	eval-rmse:24.3706
# [708]	train-rmse:3.78872	eval-rmse:24.3926
# [709]	train-rmse:3.78683	eval-rmse:24.3878
# [710]	train-rmse:3.78353	eval-rmse:24.3374
# [711]	train-rmse:3.77443	eval-rmse:24.3153
# [712]	train-rmse:3.773	eval-rmse:24.4254
# [713]	train-rmse:3.77155	eval-rmse:24.4262
# [714]	train-rmse:3.76427	eval-rmse:24.4086
# [715]	train-rmse:3.76028	eval-rmse:24.4024
# [716]	train-rmse:3.75389	eval-rmse:24.4136
# [717]	train-rmse:3.75156	eval-rmse:24.4113
# [718]	train-rmse:3.74564	eval-rmse:24.4081
# [719]	train-rmse:3.73748	eval-rmse:24.4043
# [720]	train-rmse:3.73771	eval-rmse:24.4081
# [721]	train-rmse:3.73781	eval-rmse:24.4007
# [722]	train-rmse:3.7331	eval-rmse:24.4008
# [723]	train-rmse:3.72407	eval-rmse:24.4159
# [724]	train-rmse:3.71665	eval-rmse:24.3569
# [725]	train-rmse:3.70431	eval-rmse:24.3602
# [726]	train-rmse:3.70301	eval-rmse:24.3496
# [727]	train-rmse:3.70268	eval-rmse:24.355
# [728]	train-rmse:3.69889	eval-rmse:24.3359
# [729]	train-rmse:3.69904	eval-rmse:24.3302
# [730]	train-rmse:3.69053	eval-rmse:24.3453
# [731]	train-rmse:3.68292	eval-rmse:24.3471
# [732]	train-rmse:3.67153	eval-rmse:24.3341
# [733]	train-rmse:3.66197	eval-rmse:24.3271
# [734]	train-rmse:3.66214	eval-rmse:24.3321
# [735]	train-rmse:3.6563	eval-rmse:24.3319
# [736]	train-rmse:3.6565	eval-rmse:24.3266
# [737]	train-rmse:3.65545	eval-rmse:24.3419
# [738]	train-rmse:3.65269	eval-rmse:24.337
# [739]	train-rmse:3.65246	eval-rmse:24.2798
# [740]	train-rmse:3.65167	eval-rmse:24.2791
# [741]	train-rmse:3.64873	eval-rmse:24.2815
# [742]	train-rmse:3.63332	eval-rmse:24.2854
# [743]	train-rmse:3.62573	eval-rmse:24.2915
# [744]	train-rmse:3.62527	eval-rmse:24.2557
# [745]	train-rmse:3.62509	eval-rmse:24.2557
# [746]	train-rmse:3.62488	eval-rmse:24.2557
# [747]	train-rmse:3.6204	eval-rmse:24.2536
# [748]	train-rmse:3.61451	eval-rmse:24.2528
# [749]	train-rmse:3.61048	eval-rmse:24.2499
# [750]	train-rmse:3.60502	eval-rmse:24.2556
# [751]	train-rmse:3.59886	eval-rmse:24.254
# [752]	train-rmse:3.59904	eval-rmse:24.253
# [753]	train-rmse:3.59737	eval-rmse:24.2585
# [754]	train-rmse:3.59728	eval-rmse:24.2689
# [755]	train-rmse:3.59114	eval-rmse:24.2775
# [756]	train-rmse:3.59098	eval-rmse:24.2776
# [757]	train-rmse:3.58865	eval-rmse:24.2775
# [758]	train-rmse:3.58069	eval-rmse:24.3011
# [759]	train-rmse:3.58036	eval-rmse:24.2913
# [760]	train-rmse:3.57879	eval-rmse:24.2913
# [761]	train-rmse:3.5792	eval-rmse:24.2867
# [762]	train-rmse:3.57104	eval-rmse:24.2941
# [763]	train-rmse:3.56201	eval-rmse:24.3101
# [764]	train-rmse:3.55676	eval-rmse:24.3069
# [765]	train-rmse:3.55533	eval-rmse:24.2905
# [766]	train-rmse:3.54466	eval-rmse:24.2879
# [767]	train-rmse:3.54459	eval-rmse:24.2833
# [768]	train-rmse:3.53072	eval-rmse:24.2864
# [769]	train-rmse:3.52616	eval-rmse:24.2821
# [770]	train-rmse:3.52376	eval-rmse:24.3138
# [771]	train-rmse:3.52033	eval-rmse:24.3121
# [772]	train-rmse:3.517	eval-rmse:24.3136
# [773]	train-rmse:3.51654	eval-rmse:24.3117
# [774]	train-rmse:3.51696	eval-rmse:24.3302
# [775]	train-rmse:3.51515	eval-rmse:24.3221
# [776]	train-rmse:3.5144	eval-rmse:24.4061
# [777]	train-rmse:3.51392	eval-rmse:24.4009
# [778]	train-rmse:3.50368	eval-rmse:24.4013
# [779]	train-rmse:3.50303	eval-rmse:24.4409
# [780]	train-rmse:3.50145	eval-rmse:24.4402
# [781]	train-rmse:3.50005	eval-rmse:24.4548
# [782]	train-rmse:3.49974	eval-rmse:24.4548
# [783]	train-rmse:3.49626	eval-rmse:24.4482
# [784]	train-rmse:3.49145	eval-rmse:24.4425
# [785]	train-rmse:3.4916	eval-rmse:24.4418
# [786]	train-rmse:3.48846	eval-rmse:24.4529
# [787]	train-rmse:3.48599	eval-rmse:24.4191
# [788]	train-rmse:3.48082	eval-rmse:24.4218
# [789]	train-rmse:3.4752	eval-rmse:24.4234
# [790]	train-rmse:3.47194	eval-rmse:24.4345
# [791]	train-rmse:3.47	eval-rmse:24.4526
# [792]	train-rmse:3.46811	eval-rmse:24.4533
# [793]	train-rmse:3.46821	eval-rmse:24.4398
# [794]	train-rmse:3.46684	eval-rmse:24.4098
# [795]	train-rmse:3.46585	eval-rmse:24.3987
# [796]	train-rmse:3.46152	eval-rmse:24.3847
# [797]	train-rmse:3.45957	eval-rmse:24.3893
# [798]	train-rmse:3.45997	eval-rmse:24.4017
# [799]	train-rmse:3.46007	eval-rmse:24.4072
# [800]	train-rmse:3.45668	eval-rmse:24.4014
# [801]	train-rmse:3.44987	eval-rmse:24.4013
# [802]	train-rmse:3.44595	eval-rmse:24.3849
# [803]	train-rmse:3.44059	eval-rmse:24.3826
# [804]	train-rmse:3.43839	eval-rmse:24.3796
# [805]	train-rmse:3.43899	eval-rmse:24.3862
# [806]	train-rmse:3.43703	eval-rmse:24.3855
# [807]	train-rmse:3.43682	eval-rmse:24.3854
# [808]	train-rmse:3.43743	eval-rmse:24.3766
# [809]	train-rmse:3.43352	eval-rmse:24.3728
# [810]	train-rmse:3.42993	eval-rmse:24.3764
# [811]	train-rmse:3.43029	eval-rmse:24.3836
# [812]	train-rmse:3.42002	eval-rmse:24.3669
# [813]	train-rmse:3.41308	eval-rmse:24.3744
# [814]	train-rmse:3.41163	eval-rmse:24.3718
# [815]	train-rmse:3.40792	eval-rmse:24.3725
# [816]	train-rmse:3.40676	eval-rmse:24.4055
# [817]	train-rmse:3.40663	eval-rmse:24.4119
# [818]	train-rmse:3.40319	eval-rmse:24.3931
# [819]	train-rmse:3.40245	eval-rmse:24.3694
# [820]	train-rmse:3.40241	eval-rmse:24.3704
# [821]	train-rmse:3.40004	eval-rmse:24.361
# [822]	train-rmse:3.39866	eval-rmse:24.3614
# [823]	train-rmse:3.38945	eval-rmse:24.3616
# [824]	train-rmse:3.38745	eval-rmse:24.3628
# [825]	train-rmse:3.3844	eval-rmse:24.4051
# [826]	train-rmse:3.38128	eval-rmse:24.4
# [827]	train-rmse:3.37925	eval-rmse:24.3929
# [828]	train-rmse:3.3734	eval-rmse:24.3701
# [829]	train-rmse:3.37423	eval-rmse:24.3719
# [830]	train-rmse:3.36913	eval-rmse:24.3696
# [831]	train-rmse:3.36913	eval-rmse:24.369
# [832]	train-rmse:3.36374	eval-rmse:24.3732
# [833]	train-rmse:3.36432	eval-rmse:24.3653
# [834]	train-rmse:3.35703	eval-rmse:24.3631
# [835]	train-rmse:3.35234	eval-rmse:24.366
# [836]	train-rmse:3.34448	eval-rmse:24.3581
# [837]	train-rmse:3.33441	eval-rmse:24.3627
# [838]	train-rmse:3.33443	eval-rmse:24.357
# [839]	train-rmse:3.33404	eval-rmse:24.3674
# [840]	train-rmse:3.33082	eval-rmse:24.3246
# [841]	train-rmse:3.31979	eval-rmse:24.34
# [842]	train-rmse:3.32006	eval-rmse:24.3353
# [843]	train-rmse:3.31432	eval-rmse:24.3341
# [844]	train-rmse:3.30418	eval-rmse:24.3496
# [845]	train-rmse:3.29547	eval-rmse:24.3492
# [846]	train-rmse:3.29315	eval-rmse:24.3595
# [847]	train-rmse:3.29214	eval-rmse:24.3646
# [848]	train-rmse:3.28195	eval-rmse:24.3682
# [849]	train-rmse:3.27837	eval-rmse:24.3651
# [850]	train-rmse:3.27324	eval-rmse:24.339
# [851]	train-rmse:3.27285	eval-rmse:24.3405
# [852]	train-rmse:3.2691	eval-rmse:24.3345
# [853]	train-rmse:3.26897	eval-rmse:24.34
# [854]	train-rmse:3.26497	eval-rmse:24.3555
# [855]	train-rmse:3.26394	eval-rmse:24.3467
# [856]	train-rmse:3.26425	eval-rmse:24.3687
# [857]	train-rmse:3.26416	eval-rmse:24.3446
# [858]	train-rmse:3.25983	eval-rmse:24.3301
# [859]	train-rmse:3.25855	eval-rmse:24.3409
# [860]	train-rmse:3.25683	eval-rmse:24.3377
# [861]	train-rmse:3.25375	eval-rmse:24.337
# [862]	train-rmse:3.2511	eval-rmse:24.3344
# [863]	train-rmse:3.24449	eval-rmse:24.3545
# [864]	train-rmse:3.23977	eval-rmse:24.35
# [865]	train-rmse:3.23331	eval-rmse:24.348
# [866]	train-rmse:3.23306	eval-rmse:24.3538
# [867]	train-rmse:3.23242	eval-rmse:24.3581
# [868]	train-rmse:3.22663	eval-rmse:24.3573
# [869]	train-rmse:3.22127	eval-rmse:24.362
# [870]	train-rmse:3.22084	eval-rmse:24.3679
# [871]	train-rmse:3.21995	eval-rmse:24.4002
# [872]	train-rmse:3.21384	eval-rmse:24.4008
# [873]	train-rmse:3.2096	eval-rmse:24.3983
# [874]	train-rmse:3.20494	eval-rmse:24.402
# [875]	train-rmse:3.19805	eval-rmse:24.3972
# [876]	train-rmse:3.18861	eval-rmse:24.4014
# [877]	train-rmse:3.18857	eval-rmse:24.4114
# [878]	train-rmse:3.1839	eval-rmse:24.4135
# [879]	train-rmse:3.1814	eval-rmse:24.4154
# [880]	train-rmse:3.18018	eval-rmse:24.4195
# [881]	train-rmse:3.17756	eval-rmse:24.4259
# [882]	train-rmse:3.17145	eval-rmse:24.4212
# [883]	train-rmse:3.16366	eval-rmse:24.4193
# [884]	train-rmse:3.16013	eval-rmse:24.4198
# [885]	train-rmse:3.15842	eval-rmse:24.4194
# [886]	train-rmse:3.15659	eval-rmse:24.4156
# [887]	train-rmse:3.15533	eval-rmse:24.4131
# [888]	train-rmse:3.15475	eval-rmse:24.3553
# [889]	train-rmse:3.15443	eval-rmse:24.349
# [890]	train-rmse:3.14385	eval-rmse:24.3455
# [891]	train-rmse:3.13968	eval-rmse:24.3562
# [892]	train-rmse:3.13609	eval-rmse:24.3563
# [893]	train-rmse:3.12292	eval-rmse:24.3489
# [894]	train-rmse:3.12068	eval-rmse:24.3968
# [895]	train-rmse:3.11366	eval-rmse:24.4079
# [896]	train-rmse:3.10988	eval-rmse:24.4151
# [897]	train-rmse:3.10087	eval-rmse:24.4217
# [898]	train-rmse:3.09918	eval-rmse:24.4631
# [899]	train-rmse:3.09744	eval-rmse:24.5403
# [900]	train-rmse:3.09774	eval-rmse:24.5499
# [901]	train-rmse:3.09751	eval-rmse:24.5415
# [902]	train-rmse:3.09421	eval-rmse:24.5466
# [903]	train-rmse:3.09126	eval-rmse:24.5612
# [904]	train-rmse:3.09161	eval-rmse:24.562
# [905]	train-rmse:3.08538	eval-rmse:24.5567
# [906]	train-rmse:3.08328	eval-rmse:24.5526
# [907]	train-rmse:3.07371	eval-rmse:24.5425
# [908]	train-rmse:3.0732	eval-rmse:24.5452
# [909]	train-rmse:3.06863	eval-rmse:24.5457
# [910]	train-rmse:3.06139	eval-rmse:24.5437
# [911]	train-rmse:3.06024	eval-rmse:24.5422
# [912]	train-rmse:3.06033	eval-rmse:24.543
# [913]	train-rmse:3.0533	eval-rmse:24.5342
# [914]	train-rmse:3.05283	eval-rmse:24.5407
# [915]	train-rmse:3.04937	eval-rmse:24.5425
# [916]	train-rmse:3.0463	eval-rmse:24.5441
# [917]	train-rmse:3.04651	eval-rmse:24.5419
# [918]	train-rmse:3.04429	eval-rmse:24.5403
# [919]	train-rmse:3.04441	eval-rmse:24.5297
# [920]	train-rmse:3.0419	eval-rmse:24.5091
# [921]	train-rmse:3.04162	eval-rmse:24.5091
# [922]	train-rmse:3.04176	eval-rmse:24.5253
# [923]	train-rmse:3.03626	eval-rmse:24.5325
# [924]	train-rmse:3.0321	eval-rmse:24.5347
# [925]	train-rmse:3.02951	eval-rmse:24.5448
# [926]	train-rmse:3.02791	eval-rmse:24.5458
# [927]	train-rmse:3.03161	eval-rmse:24.5464
# [928]	train-rmse:3.02805	eval-rmse:24.5566
# [929]	train-rmse:3.02598	eval-rmse:24.5708
# [930]	train-rmse:3.01981	eval-rmse:24.5667
# [931]	train-rmse:3.01595	eval-rmse:24.5683
# [932]	train-rmse:3.01582	eval-rmse:24.5553
# [933]	train-rmse:3.01486	eval-rmse:24.5526
# [934]	train-rmse:3.00845	eval-rmse:24.5561
# [935]	train-rmse:3.0065	eval-rmse:24.5786
# [936]	train-rmse:3.00515	eval-rmse:24.5797
# [937]	train-rmse:3.00002	eval-rmse:24.5665
# [938]	train-rmse:2.99797	eval-rmse:24.567
# [939]	train-rmse:2.99712	eval-rmse:24.5742
# [940]	train-rmse:2.99725	eval-rmse:24.5671
# [941]	train-rmse:2.99642	eval-rmse:24.5502
# [942]	train-rmse:2.9939	eval-rmse:24.5504
# [943]	train-rmse:2.98769	eval-rmse:24.55
# [944]	train-rmse:2.98415	eval-rmse:24.5669
# [945]	train-rmse:2.98225	eval-rmse:24.4898
# [946]	train-rmse:2.98034	eval-rmse:24.4975
# [947]	train-rmse:2.97499	eval-rmse:24.4983
# [948]	train-rmse:2.97334	eval-rmse:24.4991
# [949]	train-rmse:2.96549	eval-rmse:24.4985
# [950]	train-rmse:2.96002	eval-rmse:24.5077
# [951]	train-rmse:2.96042	eval-rmse:24.5212
# [952]	train-rmse:2.95742	eval-rmse:24.5051
# [953]	train-rmse:2.95553	eval-rmse:24.5048
# [954]	train-rmse:2.94811	eval-rmse:24.5175
# [955]	train-rmse:2.94591	eval-rmse:24.5164
# [956]	train-rmse:2.93677	eval-rmse:24.514
# [957]	train-rmse:2.93571	eval-rmse:24.5137
# [958]	train-rmse:2.93585	eval-rmse:24.5097
# [959]	train-rmse:2.93564	eval-rmse:24.4989
# [960]	train-rmse:2.93454	eval-rmse:24.4934
# [961]	train-rmse:2.93142	eval-rmse:24.4995
# [962]	train-rmse:2.92216	eval-rmse:24.4932
# [963]	train-rmse:2.91362	eval-rmse:24.4921
# [964]	train-rmse:2.9089	eval-rmse:24.4942
# [965]	train-rmse:2.89437	eval-rmse:24.5024
# [966]	train-rmse:2.89115	eval-rmse:24.5013
# [967]	train-rmse:2.88953	eval-rmse:24.4999
# [968]	train-rmse:2.87967	eval-rmse:24.5035
# [969]	train-rmse:2.87764	eval-rmse:24.507
# [970]	train-rmse:2.87659	eval-rmse:24.5105
# [971]	train-rmse:2.87014	eval-rmse:24.5022
# [972]	train-rmse:2.86394	eval-rmse:24.497
# [973]	train-rmse:2.86417	eval-rmse:24.4995
# [974]	train-rmse:2.86305	eval-rmse:24.511
# [975]	train-rmse:2.86028	eval-rmse:24.5181
# [976]	train-rmse:2.85911	eval-rmse:24.5201
# [977]	train-rmse:2.85744	eval-rmse:24.4897
# [978]	train-rmse:2.85629	eval-rmse:24.5008
# [979]	train-rmse:2.85509	eval-rmse:24.5622
# [980]	train-rmse:2.8476	eval-rmse:24.5597
# [981]	train-rmse:2.84275	eval-rmse:24.5497
# [982]	train-rmse:2.84254	eval-rmse:24.5629
# [983]	train-rmse:2.8399	eval-rmse:24.5713
# [984]	train-rmse:2.83882	eval-rmse:24.5711
# [985]	train-rmse:2.83277	eval-rmse:24.5512
# [986]	train-rmse:2.82695	eval-rmse:24.5543
# [987]	train-rmse:2.82691	eval-rmse:24.5584
# [988]	train-rmse:2.82618	eval-rmse:24.5519
# [989]	train-rmse:2.82311	eval-rmse:24.5458
# [990]	train-rmse:2.82224	eval-rmse:24.5413
# [991]	train-rmse:2.82098	eval-rmse:24.5481
# [992]	train-rmse:2.81549	eval-rmse:24.5425
# [993]	train-rmse:2.81097	eval-rmse:24.5503
# [994]	train-rmse:2.80729	eval-rmse:24.5514
# [995]	train-rmse:2.80655	eval-rmse:24.5513
# [996]	train-rmse:2.80675	eval-rmse:24.552
# [997]	train-rmse:2.80395	eval-rmse:24.5429
# [998]	train-rmse:2.80269	eval-rmse:24.566
# [999]	train-rmse:2.80136	eval-rmse:24.5665
# [1000]	train-rmse:2.79599	eval-rmse:24.5538
# [1001]	train-rmse:2.78968	eval-rmse:24.5649
# [1002]	train-rmse:2.78185	eval-rmse:24.57
# [1003]	train-rmse:2.77986	eval-rmse:24.5706
# [1004]	train-rmse:2.77289	eval-rmse:24.5628
# [1005]	train-rmse:2.7723	eval-rmse:24.5668
# [1006]	train-rmse:2.77133	eval-rmse:24.5676
# [1007]	train-rmse:2.77042	eval-rmse:24.5728
# [1008]	train-rmse:2.76904	eval-rmse:24.5723
# [1009]	train-rmse:2.76116	eval-rmse:24.5489
# [1010]	train-rmse:2.76	eval-rmse:24.5752
# [1011]	train-rmse:2.75639	eval-rmse:24.564
# [1012]	train-rmse:2.75586	eval-rmse:24.5474
# Stopping. Best iteration:
# [12]	train-rmse:12.9467	eval-rmse:18.3031

# %%
def plot_performance(base_data, date_from, date_to, title=None):
    plt.figure(figsize=(15,3))
    if title == None:
        plt.title('From {0} To {1}'.format(date_from, date_to))
    else:
        plt.title(title)
    plt.xlabel('Time(in Years)')
    plt.ylabel('Sunspots')
    plt.plot(df1.index,df1, label='data')
    plt.plot(X_train.index,x_pred, label='train prediction')
    plt.plot(X_test.index,y_pred, label='test prediction')
    plt.legend()
    plt.xlim(left=date_from, right=date_to)

# %%
y_pred = model.predict(xgb.DMatrix(X_test))
x_pred = model.predict(xgb.DMatrix(X_train))
plot_performance(df1, df1.index[0].date(), df1.index[-1].date(),
                 'Original and Predicted Data')


plot_performance(y_test, y_test.index[0].date(), y_test.index[-1].date(),
                 'Test and Predicted Data')




plt.legend()

plt.show()

# %%
print("RMSE",np.sqrt(mean_squared_error(y_true=y_test,y_pred=y_pred)))
# Out:
# RMSE 24.547399590725348

# %%
XGBOOST_rmse = np.sqrt(mean_squared_error(y_true=y_test,y_pred=y_pred))

# %%
df2 = df.copy()

# %%
df1 = df1.dropna()

df1.reset_index(inplace=True)

df1['Month'] = pd.to_datetime(df1['Month'])

df1 = df1.set_index('Month')

# %%
arima = rescaled_original
arima_predicted = rescaled_predicted

fig,axi = plt.subplots() 
fig.set_size_inches(20,8)
plt.plot(df1.index[2000:],arima[2000:],label='Observed',alpha=0.7)
plt.plot(df1.index[2318:],arima_predicted[20:],label='ARIMA',alpha=0.7)
plt.plot(df1.index[2318:],pred_series,label='DCNN',alpha=0.7)
plt.plot(df1.index[2318:],test_predict_plot[2318:],label="LSTM",alpha=0.7)
plt.plot(df1.index[2318:],y_pred,label='XGBOOST',alpha=0.7)
plt.xlabel("Time(in Years)")
plt.ylabel("No. of Sunspots")

plt.legend(fontsize='x-large')
plt.grid()

# %%
RMSE = []
RMSE.append(arima_rmse)
RMSE.append(DCNN_rmse)
RMSE.append(LSTM_rmse)
RMSE.append(XGBOOST_rmse)

# %%
x = np.asarray(RMSE)

# %%
import seaborn as sns

sns.barplot(x=['ARIMA','DCNN','LSTM','XGBOOST'],y=x, palette="rocket")
plt.title("RMSE")
plt.ylabel("RMSE values")
# Out:
# Text(0, 0.5, 'RMSE values')
